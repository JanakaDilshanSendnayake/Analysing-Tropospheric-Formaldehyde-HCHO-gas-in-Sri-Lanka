# %%
import pandas as pd
from pmdarima import auto_arima
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Colombo

# %%
# Load dataset
data = pd.read_csv(r"..\processed data\temp\colombo_fomaldehyde.csv")
data.drop(columns=['Location', 'Next_Date'], inplace=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

# # Determine best parameters using auto_arima
# auto_model = auto_arima(train_data['HCHO_reading'], seasonal=True, m=12,  # assuming hourly data
#                         stepwise=False, trace=True,
#                         error_action='ignore', suppress_warnings=True)

# # Extracting best parameters
# best_order = auto_model.order
# best_seasonal_order = auto_model.seasonal_order

best_order = (5,0,5)
best_seasonal_order = (0,0,0,12)

print("Best SARIMA Order:", best_order)
print("Best Seasonal Order:", best_seasonal_order)

# Train SARIMA model with best parameters
model = SARIMAX(train_data['HCHO_reading'], order=best_order, seasonal_order=best_seasonal_order)
sarima_model = model.fit()

# Forecast
history = train_data['HCHO_reading'].values.tolist()
predictions = []
for t in range(len(test_data)):
    model = SARIMAX(history, order=best_order, seasonal_order=best_seasonal_order)
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_data['HCHO_reading'].iloc[t]
    history.append(obs)

# Evaluate the model
test_mse = mean_squared_error(test_data['HCHO_reading'], predictions)
test_r2 = r2_score(test_data['HCHO_reading'], predictions)
test_mae = mean_absolute_error(test_data['HCHO_reading'], predictions)

print(f'Test MSE: {test_mse}')
print(f'Test R2 Score: {test_r2}')
print(f'Test MAE: {test_mae}')

# Plotting
plt.figure(figsize=(20, 6))
plt.plot(test_data.index, test_data['HCHO_reading'], label='Actual Test')
plt.plot(test_data.index, predictions, color='red', label='Predicted Test')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# Best SARIMA Order: (5, 0, 5)
# Best Seasonal Order: (0, 0, 0, 12)
# Test MSE: 5.4480047230809555e-09
# Test R2 Score: 0.22579799645728205
# Test MAE: 5.632327638472099e-05

# %% [markdown]
# # Matara

# %%
# Load dataset
data = pd.read_csv(r"..\processed data\temp\matara_fomaldehyde.csv")
data.drop(columns=['Location', 'Next_Date'], inplace=True)
data['Current_Date'] = pd.to_datetime(data['Current_Date'])
data.set_index('Current_Date', inplace=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

# Determine best parameters using auto_arima
auto_model = auto_arima(train_data['HCHO_reading'], seasonal=True, m=12,
                        stepwise=True, trace=True,
                        error_action='ignore', suppress_warnings=True)

# Extracting best parameters
best_order = auto_model.order
best_seasonal_order = auto_model.seasonal_order

print("Best SARIMA Order:", best_order)
print("Best Seasonal Order:", best_seasonal_order)

# Train SARIMA model with best parameters
model = SARIMAX(train_data['HCHO_reading'], order=best_order, seasonal_order=best_seasonal_order)
sarima_model = model.fit()

# Forecast
history = train_data['HCHO_reading'].values.tolist()
predictions = []
for t in range(len(test_data)):
    model = SARIMAX(history, order=best_order, seasonal_order=best_seasonal_order)
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_data['HCHO_reading'].iloc[t]
    history.append(obs)

# Evaluate the model
test_mse = mean_squared_error(test_data['HCHO_reading'], predictions)
test_r2 = r2_score(test_data['HCHO_reading'], predictions)
test_mae = mean_absolute_error(test_data['HCHO_reading'], predictions)

print(f'Test MSE: {test_mse}')
print(f'Test R2 Score: {test_r2}')
print(f'Test MAE: {test_mae}')

# Plotting
plt.figure(figsize=(20, 6))
plt.plot(test_data.index, test_data['HCHO_reading'], label='Actual Test')
plt.plot(test_data.index, predictions, color='red', label='Predicted Test')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[24] intercept   : AIC=inf, Time=5.73 sec
#  ARIMA(0,0,0)(0,0,0)[24] intercept   : AIC=-23982.589, Time=0.16 sec
#  ARIMA(1,0,0)(1,0,0)[24] intercept   : AIC=-23683.495, Time=3.64 sec
#  ARIMA(0,0,1)(0,0,1)[24] intercept   : AIC=-24107.695, Time=2.84 sec
#  ARIMA(0,0,0)(0,0,0)[24]             : AIC=-22512.992, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[24] intercept   : AIC=-24109.223, Time=0.58 sec
#  ARIMA(0,0,1)(1,0,0)[24] intercept   : AIC=-23623.724, Time=2.40 sec
#  ARIMA(0,0,1)(1,0,1)[24] intercept   : AIC=inf, Time=8.10 sec
#  ARIMA(1,0,1)(0,0,0)[24] intercept   : AIC=-24207.256, Time=0.68 sec
#  ARIMA(1,0,1)(1,0,0)[24] intercept   : AIC=-23699.576, Time=5.35 sec
#  ARIMA(1,0,1)(0,0,1)[24] intercept   : AIC=-24205.053, Time=3.37 sec
#  ARIMA(1,0,1)(1,0,1)[24] intercept   : AIC=inf, Time=4.87 sec
#  ARIMA(1,0,0)(0,0,0)[24] intercept   : AIC=-24186.034, Time=0.52 sec
#  ARIMA(2,0,1)(0,0,0)[24] intercept   : AIC=-24218.489, Time=1.50 sec
#  ARIMA(2,0,1)(1,0,0)[24] intercept   : AIC=-23708.607, Time=4.35 sec
#  ARIMA(2,0,1)(0,0,1)[24] intercept   : AIC=-24216.423, Time=4.76 sec
#  ARIMA(2,0,1)(1,0,1)[24] intercept   : AIC=inf, Time=5.20 sec
#  ARIMA(2,0,0)(0,0,0)[24] intercept   : AIC=-24220.835, Time=1.01 sec
#  ARIMA(2,0,0)(1,0,0)[24] intercept   : AIC=-23712.809, Time=4.07 sec
#  ARIMA(2,0,0)(0,0,1)[24] intercept   : AIC=-24218.759, Time=4.18 sec
#  ARIMA(2,0,0)(1,0,1)[24] intercept   : AIC=inf, Time=4.94 sec
#  ARIMA(3,0,0)(0,0,0)[24] intercept   : AIC=-24219.986, Time=0.39 sec
#  ARIMA(3,0,1)(0,0,0)[24] intercept   : AIC=-24215.734, Time=0.44 sec
#  ARIMA(2,0,0)(0,0,0)[24]             : AIC=-23998.875, Time=0.39 sec
#
# Best model:  ARIMA(2,0,0)(0,0,0)[24] intercept
# Total fit time: 69.560 seconds
# Best SARIMA Order: (2, 0, 0)
# Best Seasonal Order: (0, 0, 0, 24)
# Test MSE: 4.449809682376673e-09
# Test R2 Score: 0.029179849390996826
# Test MAE: 4.670216414293775e-05

# %% [markdown]
# # Kandy

# %%
# Load dataset
data = pd.read_csv(r"..\processed data\temp\kandy_fomaldehyde.csv")
data.drop(columns=['Location', 'Next_Date'], inplace=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

# Determine best parameters using auto_arima
auto_model = auto_arima(train_data['HCHO_reading'], seasonal=True, m=12,
                        stepwise=True, trace=True,
                        error_action='ignore', suppress_warnings=True)

# Extracting best parameters
best_order = auto_model.order
best_seasonal_order = auto_model.seasonal_order


print("Best SARIMA Order:", best_order)
print("Best Seasonal Order:", best_seasonal_order)

# Train SARIMA model with best parameters
model = SARIMAX(train_data['HCHO_reading'], order=best_order, seasonal_order=best_seasonal_order)
sarima_model = model.fit()

# Forecast
history = train_data['HCHO_reading'].values.tolist()
predictions = []
for t in range(len(test_data)):
    model = SARIMAX(history, order=best_order, seasonal_order=best_seasonal_order)
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_data['HCHO_reading'].iloc[t]
    history.append(obs)

# Evaluate the model
test_mse = mean_squared_error(test_data['HCHO_reading'], predictions)
test_r2 = r2_score(test_data['HCHO_reading'], predictions)
test_mae = mean_absolute_error(test_data['HCHO_reading'], predictions)

print(f'Test MSE: {test_mse}')
print(f'Test R2 Score: {test_r2}')
print(f'Test MAE: {test_mae}')

# Plotting
plt.figure(figsize=(20, 6))
plt.plot(test_data.index, test_data['HCHO_reading'], label='Actual Test')
plt.plot(test_data.index, predictions, color='red', label='Predicted Test')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=-23936.873, Time=2.97 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=-23812.002, Time=0.19 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=-23513.334, Time=1.73 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=-23948.451, Time=1.45 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=-22127.952, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=-23937.811, Time=0.67 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=-23656.588, Time=2.71 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=-23949.397, Time=3.46 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=-23748.088, Time=6.61 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=-23829.770, Time=2.86 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=-24067.789, Time=3.85 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=-24077.165, Time=1.97 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=-24075.982, Time=0.69 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=-24022.028, Time=1.99 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=-23545.110, Time=1.70 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=-24039.944, Time=5.90 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=-24043.924, Time=1.42 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=-24080.889, Time=1.69 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=-24080.976, Time=0.84 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=-23543.202, Time=0.93 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=-24050.199, Time=2.73 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=-24086.888, Time=0.42 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=-23541.204, Time=1.02 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=-24086.286, Time=1.50 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=-23988.542, Time=3.40 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=-24041.574, Time=0.24 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=-24095.285, Time=0.46 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=-23536.337, Time=2.27 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=-24093.317, Time=1.90 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=-24056.230, Time=2.89 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=-24095.513, Time=0.47 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=-23533.023, Time=2.49 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=-24092.747, Time=0.80 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=-24033.635, Time=3.10 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=-24096.522, Time=0.57 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : AIC=-23533.397, Time=3.18 sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : AIC=-24093.522, Time=0.96 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : AIC=-24038.940, Time=4.15 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : AIC=-24092.833, Time=0.75 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=-24091.610, Time=0.54 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : AIC=-23982.823, Time=0.64 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[12] intercept
# Total fit time: 78.212 seconds
# Best SARIMA Order: (5, 0, 0)
# Best Seasonal Order: (0, 0, 0, 12)
# Test MSE: 4.275822669283146e-09
# Test R2 Score: -0.012295192276305711
# Test MAE: 4.7602426524266084e-05

# %% [markdown]
# # Jaffna

# %%
# Load dataset
data = pd.read_csv(r"..\processed data\temp\jaffna_fomaldehyde.csv")
data.drop(columns=['Location', 'Next_Date'], inplace=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

# Determine best parameters using auto_arima
auto_model = auto_arima(train_data['HCHO_reading'], seasonal=True, m=12,
                        stepwise=True, trace=True,
                        error_action='ignore', suppress_warnings=True)

# Extracting best parameters
best_order = auto_model.order
best_seasonal_order = auto_model.seasonal_order


print("Best SARIMA Order:", best_order)
print("Best Seasonal Order:", best_seasonal_order)

# Train SARIMA model with best parameters
model = SARIMAX(train_data['HCHO_reading'], order=best_order, seasonal_order=best_seasonal_order)
sarima_model = model.fit()

# Forecast
history = train_data['HCHO_reading'].values.tolist()
predictions = []
for t in range(len(test_data)):
    model = SARIMAX(history, order=best_order, seasonal_order=best_seasonal_order)
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_data['HCHO_reading'].iloc[t]
    history.append(obs)

# Evaluate the model
test_mse = mean_squared_error(test_data['HCHO_reading'], predictions)
test_r2 = r2_score(test_data['HCHO_reading'], predictions)
test_mae = mean_absolute_error(test_data['HCHO_reading'], predictions)

print(f'Test MSE: {test_mse}')
print(f'Test R2 Score: {test_r2}')
print(f'Test MAE: {test_mae}')

# Plotting
plt.figure(figsize=(20, 6))
plt.plot(test_data.index, test_data['HCHO_reading'], label='Actual Test')
plt.plot(test_data.index, predictions, color='red', label='Predicted Test')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=-24217.395, Time=3.83 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=-24036.209, Time=0.17 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=-23577.520, Time=1.37 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=-24126.410, Time=1.42 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=-22210.015, Time=0.09 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=-24237.203, Time=2.44 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=-24244.070, Time=1.11 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=-23599.565, Time=1.24 sec
#  ARIMA(1,0,2)(0,0,0)[12] intercept   : AIC=-24235.579, Time=1.05 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=-24241.878, Time=0.91 sec
#  ARIMA(3,0,2)(0,0,0)[12] intercept   : AIC=-24227.080, Time=1.24 sec
#  ARIMA(2,0,3)(0,0,0)[12] intercept   : AIC=-24247.188, Time=1.26 sec
#  ARIMA(2,0,3)(1,0,0)[12] intercept   : AIC=-23605.828, Time=1.75 sec
#  ARIMA(2,0,3)(0,0,1)[12] intercept   : AIC=-24239.916, Time=2.39 sec
#  ARIMA(2,0,3)(1,0,1)[12] intercept   : AIC=-24156.210, Time=2.94 sec
#  ARIMA(1,0,3)(0,0,0)[12] intercept   : AIC=-24228.276, Time=1.04 sec
#  ARIMA(3,0,3)(0,0,0)[12] intercept   : AIC=-24251.588, Time=1.71 sec
#  ARIMA(3,0,3)(1,0,0)[12] intercept   : AIC=-23593.659, Time=3.07 sec
#  ARIMA(3,0,3)(0,0,1)[12] intercept   : AIC=-24242.772, Time=2.93 sec
#  ARIMA(3,0,3)(1,0,1)[12] intercept   : AIC=-24178.780, Time=3.70 sec
#  ARIMA(4,0,3)(0,0,0)[12] intercept   : AIC=-24249.818, Time=1.96 sec
#  ARIMA(3,0,4)(0,0,0)[12] intercept   : AIC=-24251.735, Time=1.93 sec
#  ARIMA(3,0,4)(1,0,0)[12] intercept   : AIC=-23590.296, Time=1.88 sec
#  ARIMA(3,0,4)(0,0,1)[12] intercept   : AIC=-24242.521, Time=4.25 sec
#  ARIMA(3,0,4)(1,0,1)[12] intercept   : AIC=-24145.650, Time=3.85 sec
#  ARIMA(2,0,4)(0,0,0)[12] intercept   : AIC=-24242.917, Time=1.38 sec
#  ARIMA(4,0,4)(0,0,0)[12] intercept   : AIC=-24247.382, Time=1.82 sec
#  ARIMA(3,0,5)(0,0,0)[12] intercept   : AIC=-24251.130, Time=2.23 sec
#  ARIMA(2,0,5)(0,0,0)[12] intercept   : AIC=-24235.368, Time=1.58 sec
#  ARIMA(4,0,5)(0,0,0)[12] intercept   : AIC=-24246.782, Time=2.01 sec
#  ARIMA(3,0,4)(0,0,0)[12]             : AIC=-24186.188, Time=0.91 sec
#
# Best model:  ARIMA(3,0,4)(0,0,0)[12] intercept
# Total fit time: 59.466 seconds
# Best SARIMA Order: (3, 0, 4)
# Best Seasonal Order: (0, 0, 0, 12)
# Test MSE: 3.4521778504185506e-09
# Test R2 Score: 0.05590431604772761
# Test MAE: 4.56613391679797e-05

# %% [markdown]
# # Monaragala

# %%
# Load dataset
data = pd.read_csv(r"..\processed data\temp\monaragala_fomaldehyde.csv")
data.drop(columns=['Location', 'Next_Date'], inplace=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

# Determine best parameters using auto_arima
auto_model = auto_arima(train_data['HCHO_reading'], seasonal=True, m=12,
                        stepwise=True, trace=True,
                        error_action='ignore', suppress_warnings=True)

# Extracting best parameters
best_order = auto_model.order
best_seasonal_order = auto_model.seasonal_order


print("Best SARIMA Order:", best_order)
print("Best Seasonal Order:", best_seasonal_order)

# Train SARIMA model with best parameters
model = SARIMAX(train_data['HCHO_reading'], order=best_order, seasonal_order=best_seasonal_order)
sarima_model = model.fit()

# Forecast
history = train_data['HCHO_reading'].values.tolist()
predictions = []
for t in range(len(test_data)):
    model = SARIMAX(history, order=best_order, seasonal_order=best_seasonal_order)
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_data['HCHO_reading'].iloc[t]
    history.append(obs)

# Evaluate the model
test_mse = mean_squared_error(test_data['HCHO_reading'], predictions)
test_r2 = r2_score(test_data['HCHO_reading'], predictions)
test_mae = mean_absolute_error(test_data['HCHO_reading'], predictions)

print(f'Test MSE: {test_mse}')
print(f'Test R2 Score: {test_r2}')
print(f'Test MAE: {test_mae}')

# Plotting
plt.figure(figsize=(20, 6))
plt.plot(test_data.index, test_data['HCHO_reading'], label='Actual Test')
plt.plot(test_data.index, predictions, color='red', label='Predicted Test')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=-23786.922, Time=2.96 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=-23600.607, Time=0.15 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=-23218.469, Time=1.53 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=-23703.781, Time=1.26 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=-21709.738, Time=0.08 sec
#  ARIMA(2,0,2)(0,0,1)[12] intercept   : AIC=-23847.855, Time=2.72 sec
#  ARIMA(2,0,2)(0,0,0)[12] intercept   : AIC=-23846.686, Time=1.20 sec
#  ARIMA(2,0,2)(0,0,2)[12] intercept   : AIC=-23844.290, Time=6.15 sec
#  ARIMA(2,0,2)(1,0,0)[12] intercept   : AIC=-23235.393, Time=2.78 sec
#  ARIMA(2,0,2)(1,0,2)[12] intercept   : AIC=inf, Time=4.41 sec
#  ARIMA(1,0,2)(0,0,1)[12] intercept   : AIC=-23834.075, Time=1.83 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=-23841.458, Time=1.30 sec
#  ARIMA(3,0,2)(0,0,1)[12] intercept   : AIC=-23834.204, Time=2.24 sec
#  ARIMA(2,0,3)(0,0,1)[12] intercept   : AIC=-23847.872, Time=2.26 sec
#  ARIMA(2,0,3)(0,0,0)[12] intercept   : AIC=-23847.765, Time=1.13 sec
#  ARIMA(2,0,3)(1,0,1)[12] intercept   : AIC=-23427.947, Time=2.85 sec
#  ARIMA(2,0,3)(0,0,2)[12] intercept   : AIC=-23844.721, Time=5.10 sec
#  ARIMA(2,0,3)(1,0,0)[12] intercept   : AIC=-23235.185, Time=2.78 sec
#  ARIMA(2,0,3)(1,0,2)[12] intercept   : AIC=inf, Time=5.94 sec
#  ARIMA(1,0,3)(0,0,1)[12] intercept   : AIC=-23819.695, Time=2.06 sec
#  ARIMA(3,0,3)(0,0,1)[12] intercept   : AIC=-23835.312, Time=2.46 sec
#  ARIMA(2,0,4)(0,0,1)[12] intercept   : AIC=-23849.674, Time=3.24 sec
#  ARIMA(2,0,4)(0,0,0)[12] intercept   : AIC=-23852.126, Time=1.50 sec
#  ARIMA(2,0,4)(1,0,0)[12] intercept   : AIC=-23231.653, Time=2.54 sec
#  ARIMA(2,0,4)(1,0,1)[12] intercept   : AIC=-22846.142, Time=1.99 sec
#  ARIMA(1,0,4)(0,0,0)[12] intercept   : AIC=-23824.240, Time=1.23 sec
#  ARIMA(3,0,4)(0,0,0)[12] intercept   : AIC=-23855.277, Time=1.50 sec
#  ARIMA(3,0,4)(1,0,0)[12] intercept   : AIC=-23214.692, Time=6.04 sec
#  ARIMA(3,0,4)(0,0,1)[12] intercept   : AIC=-23851.824, Time=3.35 sec
#  ARIMA(3,0,4)(1,0,1)[12] intercept   : AIC=-23149.469, Time=3.96 sec
#  ARIMA(3,0,3)(0,0,0)[12] intercept   : AIC=-23832.314, Time=1.38 sec
#  ARIMA(4,0,4)(0,0,0)[12] intercept   : AIC=-23855.109, Time=1.72 sec
#  ARIMA(3,0,5)(0,0,0)[12] intercept   : AIC=-23850.351, Time=1.94 sec
#  ARIMA(2,0,5)(0,0,0)[12] intercept   : AIC=-23845.061, Time=1.64 sec
#  ARIMA(4,0,3)(0,0,0)[12] intercept   : AIC=-23828.298, Time=1.46 sec
#  ARIMA(4,0,5)(0,0,0)[12] intercept   : AIC=-23851.388, Time=1.83 sec
#  ARIMA(3,0,4)(0,0,0)[12]             : AIC=-23813.303, Time=0.85 sec
#
# Best model:  ARIMA(3,0,4)(0,0,0)[12] intercept
# Total fit time: 89.425 seconds
# Best SARIMA Order: (3, 0, 4)
# Best Seasonal Order: (0, 0, 0, 12)
# Test MSE: 4.728536497419145e-09
# Test R2 Score: 0.2843356721592787
# Test MAE: 5.114483120566507e-05

# %% [markdown]
# # Kurunegala

# %%
# Load dataset
data = pd.read_csv(r"..\processed data\temp\kurunegala_fomaldehyde.csv")
data.drop(columns=['Location', 'Next_Date'], inplace=True)

train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

# Determine best parameters using auto_arima
auto_model = auto_arima(train_data['HCHO_reading'], seasonal=True, m=12,
                        stepwise=True, trace=True,
                        error_action='ignore', suppress_warnings=True)

# Extracting best parameters
best_order = auto_model.order
best_seasonal_order = auto_model.seasonal_order


print("Best SARIMA Order:", best_order)
print("Best Seasonal Order:", best_seasonal_order)

# Train SARIMA model with best parameters
model = SARIMAX(train_data['HCHO_reading'], order=best_order, seasonal_order=best_seasonal_order)
sarima_model = model.fit()

# Forecast
history = train_data['HCHO_reading'].values.tolist()
predictions = []
for t in range(len(test_data)):
    model = SARIMAX(history, order=best_order, seasonal_order=best_seasonal_order)
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_data['HCHO_reading'].iloc[t]
    history.append(obs)

# Evaluate the model
test_mse = mean_squared_error(test_data['HCHO_reading'], predictions)
test_r2 = r2_score(test_data['HCHO_reading'], predictions)
test_mae = mean_absolute_error(test_data['HCHO_reading'], predictions)

print(f'Test MSE: {test_mse}')
print(f'Test R2 Score: {test_r2}')
print(f'Test MAE: {test_mae}')

# Plotting
plt.figure(figsize=(20, 6))
plt.plot(test_data.index, test_data['HCHO_reading'], label='Actual Test')
plt.plot(test_data.index, predictions, color='red', label='Predicted Test')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[12] intercept   : AIC=inf, Time=2.60 sec
#  ARIMA(0,0,0)(0,0,0)[12] intercept   : AIC=-23772.662, Time=0.17 sec
#  ARIMA(1,0,0)(1,0,0)[12] intercept   : AIC=-23222.890, Time=0.74 sec
#  ARIMA(0,0,1)(0,0,1)[12] intercept   : AIC=-23840.391, Time=1.41 sec
#  ARIMA(0,0,0)(0,0,0)[12]             : AIC=-21633.376, Time=0.08 sec
#  ARIMA(0,0,1)(0,0,0)[12] intercept   : AIC=-23824.052, Time=0.59 sec
#  ARIMA(0,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=3.20 sec
#  ARIMA(0,0,1)(0,0,2)[12] intercept   : AIC=-23846.168, Time=3.61 sec
#  ARIMA(0,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=6.28 sec
#  ARIMA(0,0,0)(0,0,2)[12] intercept   : AIC=-23800.137, Time=2.76 sec
#  ARIMA(1,0,1)(0,0,2)[12] intercept   : AIC=-23948.277, Time=5.32 sec
#  ARIMA(1,0,1)(0,0,1)[12] intercept   : AIC=-23948.926, Time=2.15 sec
#  ARIMA(1,0,1)(0,0,0)[12] intercept   : AIC=-23948.111, Time=0.76 sec
#  ARIMA(1,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=5.33 sec
#  ARIMA(1,0,1)(1,0,0)[12] intercept   : AIC=-23283.312, Time=1.80 sec
#  ARIMA(1,0,1)(1,0,2)[12] intercept   : AIC=inf, Time=5.38 sec
#  ARIMA(1,0,0)(0,0,1)[12] intercept   : AIC=-23910.870, Time=1.22 sec
#  ARIMA(2,0,1)(0,0,1)[12] intercept   : AIC=-23956.832, Time=2.16 sec
#  ARIMA(2,0,1)(0,0,0)[12] intercept   : AIC=-23957.648, Time=0.84 sec
#  ARIMA(2,0,1)(1,0,0)[12] intercept   : AIC=-23266.876, Time=2.00 sec
#  ARIMA(2,0,1)(1,0,1)[12] intercept   : AIC=inf, Time=3.35 sec
#  ARIMA(2,0,0)(0,0,0)[12] intercept   : AIC=-23966.900, Time=0.79 sec
#  ARIMA(2,0,0)(1,0,0)[12] intercept   : AIC=-23239.687, Time=1.58 sec
#  ARIMA(2,0,0)(0,0,1)[12] intercept   : AIC=-23962.210, Time=0.79 sec
#  ARIMA(2,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=2.17 sec
#  ARIMA(1,0,0)(0,0,0)[12] intercept   : AIC=-23911.420, Time=0.48 sec
#  ARIMA(3,0,0)(0,0,0)[12] intercept   : AIC=-23986.658, Time=0.72 sec
#  ARIMA(3,0,0)(1,0,0)[12] intercept   : AIC=-23242.214, Time=2.10 sec
#  ARIMA(3,0,0)(0,0,1)[12] intercept   : AIC=-23979.634, Time=0.72 sec
#  ARIMA(3,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=24.12 sec
#  ARIMA(4,0,0)(0,0,0)[12] intercept   : AIC=-23997.578, Time=1.39 sec
#  ARIMA(4,0,0)(1,0,0)[12] intercept   : AIC=-23238.156, Time=1.21 sec
#  ARIMA(4,0,0)(0,0,1)[12] intercept   : AIC=-23989.194, Time=0.81 sec
#  ARIMA(4,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=2.87 sec
#  ARIMA(5,0,0)(0,0,0)[12] intercept   : AIC=-24007.640, Time=0.56 sec
#  ARIMA(5,0,0)(1,0,0)[12] intercept   : AIC=-23242.957, Time=2.11 sec
#  ARIMA(5,0,0)(0,0,1)[12] intercept   : AIC=-23998.138, Time=0.96 sec
#  ARIMA(5,0,0)(1,0,1)[12] intercept   : AIC=inf, Time=3.63 sec
#  ARIMA(5,0,1)(0,0,0)[12] intercept   : AIC=-24004.229, Time=0.67 sec
#  ARIMA(4,0,1)(0,0,0)[12] intercept   : AIC=-23994.248, Time=0.56 sec
#  ARIMA(5,0,0)(0,0,0)[12]             : AIC=-23905.952, Time=1.10 sec
#
# Best model:  ARIMA(5,0,0)(0,0,0)[12] intercept
# Total fit time: 101.141 seconds
# Best SARIMA Order: (5, 0, 0)
# Best Seasonal Order: (0, 0, 0, 12)
# Test MSE: 4.439565462975659e-09
# Test R2 Score: 0.08600767218616989
# Test MAE: 5.026240355932825e-05

# %% [markdown]
# # Nuwara Eliya

# %%
# Load dataset
data = pd.read_csv(r"..\processed data\temp\nuwara_eliya_fomaldehyde.csv")
data.drop(columns=['Location', 'Next_Date'], inplace=True)
data['Current_Date'] = pd.to_datetime(data['Current_Date'])

# Test size can be adjusted based on your needs 
train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

# Determine best parameters using auto_arima
auto_model = auto_arima(train_data['HCHO_reading'], seasonal=True, m=24,  # assuming hourly data
                        stepwise=True, trace=True,
                        error_action='ignore', suppress_warnings=True)

# Extracting best parameters
best_order = auto_model.order
best_seasonal_order = auto_model.seasonal_order

print("Best SARIMA Order:", best_order)
print("Best Seasonal Order:", best_seasonal_order)

# Train SARIMA model with best parameters
model = SARIMAX(train_data['HCHO_reading'], order=best_order, seasonal_order=best_seasonal_order)
sarima_model = model.fit()

# Forecast
history = train_data['HCHO_reading'].values.tolist()
predictions = []
for t in range(len(test_data)):
    model = SARIMAX(history, order=best_order, seasonal_order=best_seasonal_order)
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test_data['HCHO_reading'].iloc[t]
    history.append(obs)

# Evaluate the model
test_mse = mean_squared_error(test_data['HCHO_reading'], predictions)
test_r2 = r2_score(test_data['HCHO_reading'], predictions)
test_mae = mean_absolute_error(test_data['HCHO_reading'], predictions)

print(f'Test MSE: {test_mse}')
print(f'Test R2 Score: {test_r2}')
print(f'Test MAE: {test_mae}')

# Plotting
plt.figure(figsize=(20, 6))
plt.plot(test_data.index, test_data['HCHO_reading'], label='Actual Test')
plt.plot(test_data.index, predictions, color='red', label='Predicted Test')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.title('Actual vs. Predicted Values')
plt.legend()
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(1,0,1)[24] intercept   : AIC=inf, Time=6.87 sec
#  ARIMA(0,0,0)(0,0,0)[24] intercept   : AIC=-23945.687, Time=0.19 sec
#  ARIMA(1,0,0)(1,0,0)[24] intercept   : AIC=-23729.436, Time=3.95 sec
#  ARIMA(0,0,1)(0,0,1)[24] intercept   : AIC=-24101.863, Time=3.69 sec
#  ARIMA(0,0,0)(0,0,0)[24]             : AIC=-22600.221, Time=0.09 sec
#  ARIMA(0,0,1)(0,0,0)[24] intercept   : AIC=-24107.073, Time=0.74 sec
#  ARIMA(0,0,1)(1,0,0)[24] intercept   : AIC=-23641.044, Time=2.92 sec
#  ARIMA(0,0,1)(1,0,1)[24] intercept   : AIC=inf, Time=4.82 sec
#  ARIMA(1,0,1)(0,0,0)[24] intercept   : AIC=-24237.777, Time=0.91 sec
#  ARIMA(1,0,1)(1,0,0)[24] intercept   : AIC=-23750.094, Time=3.62 sec
#  ARIMA(1,0,1)(0,0,1)[24] intercept   : AIC=-24231.372, Time=5.25 sec
#  ARIMA(1,0,1)(1,0,1)[24] intercept   : AIC=inf, Time=5.04 sec
#  ARIMA(1,0,0)(0,0,0)[24] intercept   : AIC=-24210.052, Time=0.63 sec
#  ARIMA(2,0,1)(0,0,0)[24] intercept   : AIC=-24215.112, Time=0.61 sec
#  ARIMA(1,0,2)(0,0,0)[24] intercept   : AIC=-24237.941, Time=1.02 sec
#  ARIMA(1,0,2)(1,0,0)[24] intercept   : AIC=-23746.304, Time=2.31 sec
#  ARIMA(1,0,2)(0,0,1)[24] intercept   : AIC=-24230.888, Time=4.54 sec
#  ARIMA(1,0,2)(1,0,1)[24] intercept   : AIC=inf, Time=5.77 sec
#  ARIMA(0,0,2)(0,0,0)[24] intercept   : AIC=-24166.780, Time=0.93 sec
#  ARIMA(2,0,2)(0,0,0)[24] intercept   : AIC=-24248.706, Time=1.24 sec
#  ARIMA(2,0,2)(1,0,0)[24] intercept   : AIC=-23753.072, Time=5.36 sec
#  ARIMA(2,0,2)(0,0,1)[24] intercept   : AIC=-24241.968, Time=5.38 sec
#  ARIMA(3,0,2)(0,0,0)[24] intercept   : AIC=-24254.932, Time=1.48 sec
#  ARIMA(3,0,2)(1,0,0)[24] intercept   : AIC=-23760.108, Time=6.28 sec
#  ARIMA(3,0,2)(0,0,1)[24] intercept   : AIC=-24248.266, Time=6.19 sec
#  ARIMA(3,0,2)(1,0,1)[24] intercept   : AIC=inf, Time=7.25 sec
#  ARIMA(3,0,1)(0,0,0)[24] intercept   : AIC=-24250.907, Time=0.53 sec
#  ARIMA(4,0,2)(0,0,0)[24] intercept   : AIC=-24246.542, Time=0.69 sec
#  ARIMA(3,0,3)(0,0,0)[24] intercept   : AIC=-24228.865, Time=0.69 sec
#  ARIMA(2,0,3)(0,0,0)[24] intercept   : AIC=-24251.180, Time=0.64 sec
#  ARIMA(4,0,1)(0,0,0)[24] intercept   : AIC=-24253.034, Time=0.63 sec
#  ARIMA(4,0,3)(0,0,0)[24] intercept   : AIC=-24235.061, Time=0.78 sec
#  ARIMA(3,0,2)(0,0,0)[24]             : AIC=-24138.202, Time=0.78 sec
#
# Best model:  ARIMA(3,0,2)(0,0,0)[24] intercept
# Total fit time: 91.859 seconds
# Best SARIMA Order: (3, 0, 2)
# Best Seasonal Order: (0, 0, 0, 24)
# Test MSE: 3.4524846242525615e-09
# Test R2 Score: 0.17578606956457687
# Test MAE: 4.073566604156215e-05

# %%
# # Load dataset
# data = pd.read_csv(r"..\processed data\temp\colombo_fomaldehyde.csv")
# data.drop(columns=['Location', 'Next_Date'], inplace=True)

# # Preprocessing
# # scaler = MinMaxScaler()
# # data['HCHO_reading'] = scaler.fit_transform(data['HCHO_reading'].values.reshape(-1, 1))

# # Test size can be adjusted based on your needs (e.g., 0.2 for 20% test data)
# train_data, test_data = train_test_split(data, test_size=0.2, shuffle=False)

# # Define SARIMA parameters
# p = 5  # Autoregression (AR) order
# d = 0  # Differencing (I) order
# q = 3  # Moving Average (MA) order
# P = 1  # Seasonal Autoregression (SAR) order
# D = 1  # Seasonal Differencing (SI) order
# Q = 1  # Seasonal Moving Average (SMA) order
# s = 24  # Seasonal period (assuming hourly data)

# # Train SARIMA model
# model = SARIMAX(train_data['HCHO_reading'], order=(p, d, q), seasonal_order=(P, D, Q, s))
# sarima_model = model.fit()

# # Forecast
# predictions = sarima_model.forecast(steps=len(test_data))

# # Evaluate the model
# test_loss = mean_squared_error(test_data['HCHO_reading'], predictions)
# test_r2 = r2_score(test_data['HCHO_reading'], predictions)

# print(f'Test MSE: {test_loss}')
# print(f'Test R2 Score: {test_r2}')

# # Plotting
# plt.figure(figsize=(20, 6))
# plt.plot(test_data.index, test_data['HCHO_reading'], label='Actual Test')
# plt.plot(test_data.index, predictions, color='red', label='Predicted Test')
# plt.xlabel('Time')
# plt.ylabel('HCHO Reading')
# plt.title('Actual vs. Predicted Values')
# plt.legend()
# plt.show()
