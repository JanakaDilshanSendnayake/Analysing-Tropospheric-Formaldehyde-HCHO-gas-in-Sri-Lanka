# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error

# %%
df=pd.read_csv(r"..\processed data\all_data_combined.csv")
df=df[df['Location']=='Colombo Proper']

# Define columns to keep
columns_to_keep = ['Current_Date','HCHO_reading', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 
                   'Population_density', 'total', 'new', 'Lockdown', 'carbonmonoxide_average', 
                   'nitrogendioxide_average', 'ozone_average']

df = df[columns_to_keep]

try:
    # Convert 'Current_Date' to DateTime format
    df['Current_Date'] = pd.to_datetime(df['Current_Date'])
    print("Conversion to DateTime format successful.")
except ValueError as e:
    print(f"Error converting to DateTime format: {e}")
    
df = df.sort_values(by='Current_Date')
df.set_index('Current_Date', inplace=True)

print(df.info())
df.head()
# Out:
# Conversion to DateTime format successful.
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2019-01-01 to 2023-12-31
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   HCHO_reading             1826 non-null   float64
#  1   PRCP                     1826 non-null   float64
#  2   TAVG                     1826 non-null   float64
#  3   TMAX                     1826 non-null   float64
#  4   TMIN                     1826 non-null   float64
#  5   Population               1826 non-null   int64
#  6   Population_density       1826 non-null   float64
#  7   total                    1826 non-null   float64
#  8   new                      1826 non-null   float64
#  9   Lockdown                 1826 non-null   int64
#  10  carbonmonoxide_average   1826 non-null   float64
#  11  nitrogendioxide_average  1826 non-null   float64
#  12  ozone_average            1826 non-null   float64
# dtypes: float64(11), int64(2)
# memory usage: 199.7 KB
# None
#               HCHO_reading  PRCP  TAVG  TMAX  TMIN  Population  \
# Current_Date
# 2019-01-01        0.000197   0.0  81.5  89.0  74.0     2448000
# 2019-01-02        0.000263   0.0  78.0  82.0  74.0     2448000
# 2019-01-03        0.000099   0.0  82.0  90.0  74.0     2448000
# 2019-01-04        0.000210   0.0  81.5  91.0  72.0     2448000
# 2019-01-05        0.000179   0.0  82.0  90.0  74.0     2448000
#
#               Population_density  total  new  Lockdown  \
# Current_Date
# 2019-01-01           3503.649635    0.0  0.0         0
# 2019-01-02           3503.649635    0.0  0.0         0
# 2019-01-03           3503.649635    0.0  0.0         0
# 2019-01-04           3503.649635    0.0  0.0         0
# 2019-01-05           3503.649635    0.0  0.0         0
#
#               carbonmonoxide_average  nitrogendioxide_average  ozone_average
# Current_Date
# 2019-01-01                  0.040408                 0.000030       0.113651
# 2019-01-02                  0.040408                 0.000031       0.113651
# 2019-01-03                  0.034717                 0.000025       0.111744
# 2019-01-04                  0.036808                 0.000029       0.113157
# 2019-01-05                  0.035529                 0.000026       0.112851

# %% [markdown]
# # Colombo

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Load the dataset
df = pd.read_csv(r"..\processed data\all_data_combined.csv")
df = df[df['Location'] == 'Colombo Proper']

# Define columns to keep
columns_to_keep = ['Current_Date', 'HCHO_reading', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 
                   'Population_density', 'total', 'new', 'Lockdown', 'carbonmonoxide_average', 
                   'nitrogendioxide_average', 'ozone_average']

df = df[columns_to_keep]

# Convert 'Current_Date' to DateTime format
df['Current_Date'] = pd.to_datetime(df['Current_Date'])

# Sort by date and set index
df = df.sort_values(by='Current_Date')
df.set_index('Current_Date', inplace=True)

# Define input features (X) and target variable (y)
X_cols = ['TMAX', 'TMIN','carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average']
y_col = ['HCHO_reading']

X = df[X_cols].values  # Features
y = df[y_col].values   # Target

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape input data to 3D array (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Define the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Train the model and capture history
history = model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_data=(X_test, y_test))

# Plot loss curve
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Predictions on test data
y_pred = model.predict(X_test)

# Rescale predictions and actuals
y_pred_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_pred), axis=1))
y_test_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_test.reshape(-1, 1)), axis=1))

# Extract the HCHO readings
y_pred_hcho = y_pred_rescaled[:, -1]
y_test_hcho = y_test_rescaled[:, -1]

# Calculate R^2 score and MAE
r2 = round(r2_score(y_test_hcho, y_pred_hcho), 4)
mae = mean_absolute_error(y_test_hcho, y_pred_hcho)
mse = mean_squared_error(y_test_hcho, y_pred_hcho)
print("R^2 Score:", r2)
print("MAE:", mae)
print("Test MSE:", mse)

# Plot predictions vs actuals
plt.figure(figsize=(10, 6))
plt.plot(df.index[-len(y_test_hcho):], y_test_hcho, label='Actuals', color='blue')
plt.plot(df.index[-len(y_pred_hcho):], y_pred_hcho, label='Predictions', color='red', linestyle='--')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.title('Actual vs Predicted HCHO Readings')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# C:\Users\janak\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.1746 - val_loss: 0.0281
# Epoch 2/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0248 - val_loss: 0.0227
# Epoch 3/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0231 - val_loss: 0.0212
# Epoch 4/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0201 - val_loss: 0.0200
# Epoch 5/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0182 - val_loss: 0.0190
# Epoch 6/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0178 - val_loss: 0.0184
# Epoch 7/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0179 - val_loss: 0.0180
# Epoch 8/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0175 - val_loss: 0.0178
# Epoch 9/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0186 - val_loss: 0.0179
# Epoch 10/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0160 - val_loss: 0.0176
# Epoch 11/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 12/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - val_loss: 0.0175
# Epoch 13/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0163 - val_loss: 0.0175
# Epoch 14/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - val_loss: 0.0174
# Epoch 15/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174 - val_loss: 0.0174
# Epoch 16/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0174 - val_loss: 0.0174
# Epoch 17/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0171 - val_loss: 0.0173
# Epoch 18/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0155 - val_loss: 0.0172
# Epoch 19/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - val_loss: 0.0174
# Epoch 20/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0166 - val_loss: 0.0178
# Epoch 21/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0173 - val_loss: 0.0172
# Epoch 22/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0165 - val_loss: 0.0172
# Epoch 23/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163 - val_loss: 0.0172
# Epoch 24/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0164 - val_loss: 0.0172
# Epoch 25/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166 - val_loss: 0.0171
# Epoch 26/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - val_loss: 0.0171
# Epoch 27/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0171
# Epoch 28/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0170 - val_loss: 0.0171
# Epoch 29/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167 - val_loss: 0.0171
# Epoch 30/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167 - val_loss: 0.0170
# Epoch 31/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0178 - val_loss: 0.0171
# Epoch 32/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174 - val_loss: 0.0170
# Epoch 33/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0166 - val_loss: 0.0174
# Epoch 34/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0177 - val_loss: 0.0172
# Epoch 35/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171 - val_loss: 0.0174
# Epoch 36/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - val_loss: 0.0171
# Epoch 37/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0173 - val_loss: 0.0170
# Epoch 38/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - val_loss: 0.0172
# Epoch 39/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0176 - val_loss: 0.0170
# Epoch 40/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167 - val_loss: 0.0171
# Epoch 41/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0177 - val_loss: 0.0170
# Epoch 42/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0164 - val_loss: 0.0172
# Epoch 43/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0179 - val_loss: 0.0170
# Epoch 44/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164 - val_loss: 0.0170
# Epoch 45/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0161 - val_loss: 0.0171
# Epoch 46/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - val_loss: 0.0170
# Epoch 47/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0173 - val_loss: 0.0170
# Epoch 48/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174 - val_loss: 0.0172
# Epoch 49/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - val_loss: 0.0170
# Epoch 50/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170 - val_loss: 0.0170
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# R^2 Score: 0.3229
# MAE: 5.2706391998442075e-05
# Test MSE: 4.76447852297744e-09

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Load the dataset
df = pd.read_csv(r"..\processed data\all_data_combined.csv")
df = df[df['Location'] == 'Colombo Proper']

# Define columns to keep
columns_to_keep = ['Current_Date', 'HCHO_reading', 
                   'PRCP', 'TAVG', 'TMAX', 'TMIN', 
                   'Population', 'Population_density', 'total', 'new', 'Lockdown', 
                   'carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average'
                  ]

df = df[columns_to_keep]

# Convert 'Current_Date' to DateTime format
df['Current_Date'] = pd.to_datetime(df['Current_Date'])
df['Year']=df['Current_Date'].dt.year
df['Month']=df['Current_Date'].dt.month
df['Day']=df['Current_Date'].dt.day

# Sort by date and set index
df = df.sort_values(by='Current_Date')
df.set_index('Current_Date', inplace=True)

# Define input features (X) and target variable (y)

X_cols = ['TMAX', 'TMIN','carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average','Year','Month','Day']
y_col = ['HCHO_reading']

X = df[X_cols].values  # Features
y = df[y_col].values   # Target

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape input data to 3D array (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# # Define the LSTM model
# model = Sequential()
# model.add(LSTM(200, input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(Dense(3))


model = Sequential([
    LSTM(200, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True, activation='relu'),
    LSTM(50, return_sequences=True, activation='relu'),
    LSTM(50, activation='relu'),
    Dense(3, activation='linear')
])


model.compile(optimizer='adam', loss='mse')
# Train the model and capture history
history = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1, validation_data=(X_test, y_test))

# Plot loss curve
plt.plot(history.history['loss'], label='Train Loss', color='navy')
plt.plot(history.history['val_loss'], label='Test Loss', color='darkorange')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Predictions on test data
y_pred = model.predict(X_test)

# Rescale predictions and actuals
y_pred_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_pred), axis=1))
y_test_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_test.reshape(-1, 1)), axis=1))

# Extract the HCHO readings
y_pred_hcho = y_pred_rescaled[:, -1]
y_test_hcho = y_test_rescaled[:, -1]

# Calculate R^2 score and MAE
r2 = round(r2_score(y_test_hcho, y_pred_hcho), 4)
mae = mean_absolute_error(y_test_hcho, y_pred_hcho)
mse = mean_squared_error(y_test_hcho, y_pred_hcho)
print("R^2 Score:", r2)
print("MAE:", mae)
print("Test MSE:", mse)

# Plot predictions vs actuals
plt.figure(figsize=(10, 6))
plt.plot(df.index[-len(y_test_hcho):], y_test_hcho, label='Actuals', color='navy')
plt.plot(df.index[-len(y_pred_hcho):], y_pred_hcho, label='Predictions', color='darkorange')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.title('Actual vs Predicted HCHO Readings')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# C:\Users\janak\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - loss: 0.2191 - val_loss: 0.0295
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0281 - val_loss: 0.0207
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0201 - val_loss: 0.0222
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0177 - val_loss: 0.0175
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0183 - val_loss: 0.0196
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0172 - val_loss: 0.0170
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0175 - val_loss: 0.0177
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0178 - val_loss: 0.0174
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0176 - val_loss: 0.0169
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0165 - val_loss: 0.0180
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0169 - val_loss: 0.0172
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0158 - val_loss: 0.0183
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0168 - val_loss: 0.0193
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0163 - val_loss: 0.0167
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0159 - val_loss: 0.0167
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0166 - val_loss: 0.0168
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0166 - val_loss: 0.0194
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0159 - val_loss: 0.0178
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0174 - val_loss: 0.0171
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0169 - val_loss: 0.0168
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0162 - val_loss: 0.0165
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0166 - val_loss: 0.0182
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0156 - val_loss: 0.0165
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0171 - val_loss: 0.0165
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0163 - val_loss: 0.0165
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0166 - val_loss: 0.0172
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0166 - val_loss: 0.0165
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0159 - val_loss: 0.0173
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0175 - val_loss: 0.0174
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0153 - val_loss: 0.0165
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0168 - val_loss: 0.0170
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0173 - val_loss: 0.0177
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0163 - val_loss: 0.0172
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0167 - val_loss: 0.0178
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0162 - val_loss: 0.0165
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0163 - val_loss: 0.0164
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0172 - val_loss: 0.0171
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0158 - val_loss: 0.0176
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0170 - val_loss: 0.0166
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0164 - val_loss: 0.0164
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0168 - val_loss: 0.0167
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0165 - val_loss: 0.0173
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0158 - val_loss: 0.0167
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0159 - val_loss: 0.0164
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0165 - val_loss: 0.0169
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0161 - val_loss: 0.0169
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0160 - val_loss: 0.0173
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0167 - val_loss: 0.0176
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0164 - val_loss: 0.0170
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0155 - val_loss: 0.0167
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0167 - val_loss: 0.0180
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0164 - val_loss: 0.0167
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0163 - val_loss: 0.0165
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0152 - val_loss: 0.0174
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0156 - val_loss: 0.0171
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0157 - val_loss: 0.0169
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0168 - val_loss: 0.0172
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0157 - val_loss: 0.0187
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0163 - val_loss: 0.0194
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0163 - val_loss: 0.0166
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0171 - val_loss: 0.0188
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0170 - val_loss: 0.0177
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0151 - val_loss: 0.0176
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0171 - val_loss: 0.0165
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0169 - val_loss: 0.0177
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0162 - val_loss: 0.0165
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0156 - val_loss: 0.0166
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0159 - val_loss: 0.0181
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0167 - val_loss: 0.0165
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0163 - val_loss: 0.0165
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0161 - val_loss: 0.0180
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0161 - val_loss: 0.0165
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0152 - val_loss: 0.0197
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0152 - val_loss: 0.0165
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0161 - val_loss: 0.0164
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0172 - val_loss: 0.0172
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0162 - val_loss: 0.0164
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0169 - val_loss: 0.0181
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0167 - val_loss: 0.0176
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0156 - val_loss: 0.0166
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0165 - val_loss: 0.0175
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0163 - val_loss: 0.0170
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0155 - val_loss: 0.0168
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0149 - val_loss: 0.0187
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0170 - val_loss: 0.0190
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0161 - val_loss: 0.0164
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0171 - val_loss: 0.0179
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0169 - val_loss: 0.0168
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0155 - val_loss: 0.0164
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0164 - val_loss: 0.0164
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0158 - val_loss: 0.0206
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0167 - val_loss: 0.0174
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0158 - val_loss: 0.0190
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0171 - val_loss: 0.0165
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0160 - val_loss: 0.0197
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0162 - val_loss: 0.0173
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0148 - val_loss: 0.0172
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0160 - val_loss: 0.0167
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0166 - val_loss: 0.0175
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# R^2 Score: 0.3005
# MAE: 5.30334453480479e-05
# Test MSE: 4.922468855099325e-09

# %%
import seaborn as sns
# Calculate the correlation matrix
correlation_matrix = df.corr(numeric_only =True)

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(20, 20))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10})
plt.title('Correlation Matrix for Numerical Features')
plt.show()

# %% [markdown]
# # Monaragala

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense,Bidirectional
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Load the dataset
df = pd.read_csv(r"..\processed data\all_data_combined.csv")
df = df[df['Location'] == 'Bibile, Monaragala']

# Define columns to keep
columns_to_keep = ['Current_Date', 'HCHO_reading', 
                   'PRCP', 'TAVG', 'TMAX', 'TMIN', 
                   'Population', 'Population_density', 'total', 'new', 'Lockdown', 
                   'carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average'
                  ]

df = df[columns_to_keep]

# Convert 'Current_Date' to DateTime format
df['Current_Date'] = pd.to_datetime(df['Current_Date'])
df['Year']=df['Current_Date'].dt.year
df['Month']=df['Current_Date'].dt.month
df['Day']=df['Current_Date'].dt.day

# Sort by date and set index
df = df.sort_values(by='Current_Date')
df.set_index('Current_Date', inplace=True)

# Define input features (X) and target variable (y)

X_cols = ['TMAX', 'TMIN','carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average','Year','Month','Day']
y_col = ['HCHO_reading']

X = df[X_cols].values  # Features
y = df[y_col].values   # Target

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape input data to 3D array (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# # Define the LSTM model
# model = Sequential()
# model.add(LSTM(200, input_shape=(X_train.shape[1], X_train.shape[2])))
# model.add(Dense(3))


# model = Sequential([
#     LSTM(400, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True, activation='relu'),
#     LSTM(400, return_sequences=True, activation='relu'),
#     LSTM(50, activation='relu'),
#     Dense(3, activation='linear')
# ])

model = Sequential([
    Bidirectional(LSTM(400, return_sequences=True, activation='relu'), input_shape=(X_train.shape[1], X_train.shape[2])),
    Bidirectional(LSTM(400, return_sequences=True, activation='relu')),
    LSTM(50, activation='relu'),
    Dense(3, activation='linear')
])


model.compile(optimizer='adam', loss='mse')
# Train the model and capture history
history = model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1, validation_data=(X_test, y_test))

# Plot loss curve
plt.plot(history.history['loss'], label='Train Loss', color='navy')
plt.plot(history.history['val_loss'], label='Test Loss', color='darkorange')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Predictions on test data
y_pred = model.predict(X_test)

# Rescale predictions and actuals
y_pred_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_pred), axis=1))
y_test_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_test.reshape(-1, 1)), axis=1))

# Extract the HCHO readings
y_pred_hcho = y_pred_rescaled[:, -1]
y_test_hcho = y_test_rescaled[:, -1]

# Calculate R^2 score and MAE
r2 = round(r2_score(y_test_hcho, y_pred_hcho), 4)
mae = mean_absolute_error(y_test_hcho, y_pred_hcho)
mse = mean_squared_error(y_test_hcho, y_pred_hcho)
print("R^2 Score:", r2)
print("MAE:", mae)
print("Test MSE:", mse)

# Plot predictions vs actuals
plt.figure(figsize=(10, 6))
plt.plot(df.index[-len(y_test_hcho):], y_test_hcho, label='Actuals', color='navy')
plt.plot(df.index[-len(y_pred_hcho):], y_pred_hcho, label='Predictions', color='darkorange')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.title('Actual vs Predicted HCHO Readings')
plt.legend()
plt.show()
# Out:
# C:\Users\janak\anaconda3\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - loss: 0.1863 - val_loss: 0.0450
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0281 - val_loss: 0.0328
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0278 - val_loss: 0.0305
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0257 - val_loss: 0.0297
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0262 - val_loss: 0.0336
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0272 - val_loss: 0.0359
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0279 - val_loss: 0.0314
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 0.0268 - val_loss: 0.0349
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0241 - val_loss: 0.0295
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0261 - val_loss: 0.0300
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0254 - val_loss: 0.0318
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0267 - val_loss: 0.0330
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0265 - val_loss: 0.0391
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0280 - val_loss: 0.0370
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0283 - val_loss: 0.0307
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 0.0265 - val_loss: 0.0356
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0271 - val_loss: 0.0304
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0255 - val_loss: 0.0303
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0251 - val_loss: 0.0301
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0243 - val_loss: 0.0301
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0254 - val_loss: 0.0302
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0245 - val_loss: 0.0304
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0269 - val_loss: 0.0313
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0250 - val_loss: 0.0305
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0271 - val_loss: 0.0324
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0263 - val_loss: 0.0306
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0267 - val_loss: 0.0305
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0272 - val_loss: 0.0297
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0247 - val_loss: 0.0300
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0261 - val_loss: 0.0312
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0257 - val_loss: 0.0326
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0251 - val_loss: 0.0310
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0253 - val_loss: 0.0294
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0243 - val_loss: 0.0323
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0238 - val_loss: 0.0300
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0249 - val_loss: 0.0308
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0264 - val_loss: 0.0317
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0266 - val_loss: 0.0296
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0251 - val_loss: 0.0340
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0249 - val_loss: 0.0316
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0248 - val_loss: 0.0322
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0272 - val_loss: 0.0296
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0234 - val_loss: 0.0291
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0247 - val_loss: 0.0321
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0255 - val_loss: 0.0301
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0247 - val_loss: 0.0297
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0264 - val_loss: 0.0335
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0276 - val_loss: 0.0283
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0242 - val_loss: 0.0301
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 0.0244 - val_loss: 0.0303
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0230 - val_loss: 0.0323
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0247 - val_loss: 0.0314
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0240 - val_loss: 0.0309
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0240 - val_loss: 0.0287
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0249 - val_loss: 0.0301
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0244 - val_loss: 0.0311
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0226 - val_loss: 0.0310
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0254 - val_loss: 0.0298
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0250 - val_loss: 0.0309
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0234 - val_loss: 0.0349
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0252 - val_loss: 0.0286
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0268 - val_loss: 0.0308
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0250 - val_loss: 0.0322
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0251 - val_loss: 0.0324
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0235 - val_loss: 0.0296
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0243 - val_loss: 0.0303
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0228 - val_loss: 0.0306
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0241 - val_loss: 0.0305
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0240 - val_loss: 0.0298
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0241 - val_loss: 0.0289
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0234 - val_loss: 0.0346
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0255 - val_loss: 0.0347
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0242 - val_loss: 0.0302
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 87ms/step - loss: 0.0241 - val_loss: 0.0292
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0251 - val_loss: 0.0284
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0257 - val_loss: 0.0323
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0244 - val_loss: 0.0299
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0246 - val_loss: 0.0295
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0250 - val_loss: 0.0325
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0235 - val_loss: 0.0289
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0226 - val_loss: 0.0305
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0232 - val_loss: 0.0313
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 4s 79ms/step - loss: 0.0245 - val_loss: 0.0307
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0246 - val_loss: 0.0306
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0258 - val_loss: 0.0299
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0249 - val_loss: 0.0294
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0238 - val_loss: 0.0304
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 0.0228 - val_loss: 0.0297
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0229 - val_loss: 0.0306
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0230 - val_loss: 0.0292
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0234 - val_loss: 0.0299
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 71ms/step - loss: 0.0233 - val_loss: 0.0305
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0247 - val_loss: 0.0295
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0224 - val_loss: 0.0294
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0247 - val_loss: 0.0287
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0242 - val_loss: 0.0289
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0218 - val_loss: 0.0295
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0232 - val_loss: 0.0294
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0244 - val_loss: 0.0296
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - loss: 0.0239 - val_loss: 0.0304
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step
# R^2 Score: 0.2024
# MAE: 5.660994135122553e-05
# Test MSE: 5.104986098362651e-09

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Load the dataset
df = pd.read_csv(r"..\processed data\all_data_combined.csv")
df = df[df['Location'] == 'Colombo Proper']

# Define columns to keep
columns_to_keep = ['Current_Date', 'HCHO_reading', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 
                   'Population_density', 'total', 'new', 'Lockdown', 'carbonmonoxide_average', 
                   'nitrogendioxide_average', 'ozone_average']

df = df[columns_to_keep]

# Convert 'Current_Date' to DateTime format
df['Current_Date'] = pd.to_datetime(df['Current_Date'])

# Sort by date and set index
df = df.sort_values(by='Current_Date')
df.set_index('Current_Date', inplace=True)

# Normalize the data


# Define input features (X) and target variable (y)
X_cols = ['TMAX', 'TMIN','carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average']
y_col = ['HCHO_reading']

X = df[X_cols]  # Features
y = df[y_col]   # Target

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape input data to 3D array (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Define the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Evaluate the model
mse = model.evaluate(X_test, y_test, verbose=0)
print("Test MSE:", mse)
# Out:
# Epoch 1/100
# C:\Users\janak\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.2320
# Epoch 2/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0322
# Epoch 3/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0265
# Epoch 4/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0245
# Epoch 5/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0204
# Epoch 6/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0194
# Epoch 7/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0179
# Epoch 8/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0183
# Epoch 9/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175
# Epoch 10/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166
# Epoch 11/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167
# Epoch 12/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.0174
# Epoch 13/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0165
# Epoch 14/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0155
# Epoch 15/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164
# Epoch 16/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0157
# Epoch 17/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0172
# Epoch 18/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0161
# Epoch 19/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0182
# Epoch 20/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167
# Epoch 21/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0164
# Epoch 22/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0157
# Epoch 23/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step - loss: 0.0173
# Epoch 24/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 0.0175
# Epoch 25/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0173
# Epoch 26/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167
# Epoch 27/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0176
# Epoch 28/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0170
# Epoch 29/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0173
# Epoch 30/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0180
# Epoch 31/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0172
# Epoch 32/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0166
# Epoch 33/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167
# Epoch 34/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0158
# Epoch 35/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0171
# Epoch 36/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0168
# Epoch 37/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 0.0181
# Epoch 38/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0165
# Epoch 39/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0151
# Epoch 40/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0177
# Epoch 41/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 839us/step - loss: 0.0176
# Epoch 42/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0162
# Epoch 43/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0164
# Epoch 44/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0178
# Epoch 45/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169
# Epoch 46/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0179
# Epoch 47/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0168
# Epoch 48/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0163
# Epoch 49/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0167
# Epoch 50/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0157
# Epoch 51/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0171
# Epoch 52/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0178
# Epoch 53/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - loss: 0.0166
# Epoch 54/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0169
# Epoch 55/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0182
# Epoch 56/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0168
# Epoch 57/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0165
# Epoch 58/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167
# Epoch 59/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0166
# Epoch 60/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0165
# Epoch 61/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0172
# Epoch 62/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179
# Epoch 63/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0156
# Epoch 64/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164
# Epoch 65/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0158
# Epoch 66/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0157
# Epoch 67/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0178
# Epoch 68/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0166
# Epoch 69/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0166
# Epoch 70/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0164
# Epoch 71/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0157
# Epoch 72/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0161
# Epoch 73/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160
# Epoch 74/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166
# Epoch 75/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0165
# Epoch 76/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0172
# Epoch 77/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171
# Epoch 78/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0170
# Epoch 79/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174
# Epoch 80/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168
# Epoch 81/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0165
# Epoch 82/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0168
# Epoch 83/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0158
# Epoch 84/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0159
# Epoch 85/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0165
# Epoch 86/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169
# Epoch 87/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.0182
# Epoch 88/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0172
# Epoch 89/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0170
# Epoch 90/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182
# Epoch 91/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167
# Epoch 92/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169
# Epoch 93/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0155
# Epoch 94/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168
# Epoch 95/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167
# Epoch 96/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0175
# Epoch 97/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0159
# Epoch 98/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169
# Epoch 99/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0180
# Epoch 100/100
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0174
# Test MSE: 0.017031528055667877

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error

# Predictions on test data
y_pred = model.predict(X_test)

# Rescale predictions and actuals
y_pred_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_pred), axis=1))
y_test_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_test.reshape(-1, 1)), axis=1))

# Extract the HCHO readings
y_pred_hcho = y_pred_rescaled[:, -1]
y_test_hcho = y_test_rescaled[:, -1]

# Calculate R^2 score and MAE
r2 = round(r2_score(y_test_hcho, y_pred_hcho), 4)
mae = mean_absolute_error(y_test_hcho, y_pred_hcho)
mse = mean_squared_error(y_test_hcho, y_pred_hcho)
print("R^2 Score:", r2)
print("MAE:", mae)
print("Test MSE:", mse)

# Plot predictions vs actuals
plt.figure(figsize=(10, 6))
plt.plot(df.index[-len(y_test_hcho):], y_test_hcho, label='Actuals', color='blue')
plt.plot(df.index[-len(y_pred_hcho):], y_pred_hcho, label='Predictions', color='red', linestyle='--')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.title('Actual vs Predicted HCHO Readings')
plt.legend()
plt.show()
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# R^2 Score: 0.3231
# MAE: 5.290152789199743e-05
# Test MSE: 4.763596162130092e-09

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_data=(X_test, y_test))

# Plot loss graph
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - val_loss: 0.0220
# Epoch 2/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0144 - val_loss: 0.0217
# Epoch 3/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0131 - val_loss: 0.0209
# Epoch 4/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0136 - val_loss: 0.0205
# Epoch 5/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0145 - val_loss: 0.0208
# Epoch 6/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0138 - val_loss: 0.0206
# Epoch 7/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0136 - val_loss: 0.0209
# Epoch 8/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0131 - val_loss: 0.0207
# Epoch 9/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - val_loss: 0.0221
# Epoch 10/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0132 - val_loss: 0.0209
# Epoch 11/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0125 - val_loss: 0.0209
# Epoch 12/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0134 - val_loss: 0.0207
# Epoch 13/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0131 - val_loss: 0.0208
# Epoch 14/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0132 - val_loss: 0.0210
# Epoch 15/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0135 - val_loss: 0.0205
# Epoch 16/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0146 - val_loss: 0.0208
# Epoch 17/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0130 - val_loss: 0.0209
# Epoch 18/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0130 - val_loss: 0.0209
# Epoch 19/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0131 - val_loss: 0.0212
# Epoch 20/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0137 - val_loss: 0.0206
# Epoch 21/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0145 - val_loss: 0.0206
# Epoch 22/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0140 - val_loss: 0.0208
# Epoch 23/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0136 - val_loss: 0.0209
# Epoch 24/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0136 - val_loss: 0.0212
# Epoch 25/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0139 - val_loss: 0.0223
# Epoch 26/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0133 - val_loss: 0.0214
# Epoch 27/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - val_loss: 0.0217
# Epoch 28/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0140 - val_loss: 0.0225
# Epoch 29/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0134 - val_loss: 0.0210
# Epoch 30/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0134 - val_loss: 0.0213
# Epoch 31/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0128 - val_loss: 0.0222
# Epoch 32/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0139 - val_loss: 0.0209
# Epoch 33/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0129 - val_loss: 0.0209
# Epoch 34/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0137 - val_loss: 0.0210
# Epoch 35/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0137 - val_loss: 0.0207
# Epoch 36/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0138 - val_loss: 0.0207
# Epoch 37/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0137 - val_loss: 0.0231
# Epoch 38/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0133 - val_loss: 0.0221
# Epoch 39/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0138 - val_loss: 0.0221
# Epoch 40/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0129 - val_loss: 0.0219
# Epoch 41/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0132 - val_loss: 0.0215
# Epoch 42/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0131 - val_loss: 0.0210
# Epoch 43/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0124 - val_loss: 0.0233
# Epoch 44/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0131 - val_loss: 0.0211
# Epoch 45/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0139 - val_loss: 0.0210
# Epoch 46/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0139 - val_loss: 0.0210
# Epoch 47/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0125 - val_loss: 0.0225
# Epoch 48/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0125 - val_loss: 0.0209
# Epoch 49/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0143 - val_loss: 0.0235
# Epoch 50/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0133 - val_loss: 0.0218

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Load the dataset
df = pd.read_csv(r"..\processed data\all_data_combined.csv")
df = df[df['Location'] == 'Colombo Proper']

# Define columns to keep
columns_to_keep = ['Current_Date', 'HCHO_reading', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 
                   'Population_density', 'total', 'new', 'Lockdown', 'carbonmonoxide_average', 
                   'nitrogendioxide_average', 'ozone_average']

df = df[columns_to_keep]

# Convert 'Current_Date' to DateTime format
df['Current_Date'] = pd.to_datetime(df['Current_Date'])

# Sort by date and set index
df = df.sort_values(by='Current_Date')
df.set_index('Current_Date', inplace=True)

# Define input features (X) and target variable (y)
X_cols = ['TMAX', 'TMIN','carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average']
y_col = ['HCHO_reading']

X = df[X_cols]  # Features
y = df[y_col]   # Target

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape input data to 3D array (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Define the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)

# Evaluate the model
mse = model.evaluate(X_test, y_test, verbose=0)
print("Test MSE:", mse)

import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error

# Predictions on test data
y_pred = model.predict(X_test)

# Rescale predictions and actuals
y_pred_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_pred), axis=1))
y_test_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_test.reshape(-1, 1)), axis=1))

# Extract the HCHO readings
y_pred_hcho = y_pred_rescaled[:, -1]
y_test_hcho = y_test_rescaled[:, -1]

# Calculate R^2 score and MAE
r2 = round(r2_score(y_test_hcho, y_pred_hcho), 4)
mae = mean_absolute_error(y_test_hcho, y_pred_hcho)
mse = mean_squared_error(y_test_hcho, y_pred_hcho)
print("R^2 Score:", r2)
print("MAE:", mae)
print("Test MSE:", mse)

# Plot predictions vs actuals
plt.figure(figsize=(10, 6))
plt.plot(df.index[-len(y_test_hcho):], y_test_hcho, label='Actuals', color='blue')
plt.plot(df.index[-len(y_pred_hcho):], y_pred_hcho, label='Predictions', color='red', linestyle='--')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.title('Actual vs Predicted HCHO Readings')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# C:\Users\janak\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 0.2535
# Epoch 2/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0373
# Epoch 3/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0224
# Epoch 4/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0198
# Epoch 5/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0207
# Epoch 6/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191
# Epoch 7/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190
# Epoch 8/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177
# Epoch 9/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182
# Epoch 10/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173
# Epoch 11/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163
# Epoch 12/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166
# Epoch 13/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0174
# Epoch 14/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170
# Epoch 15/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160
# Epoch 16/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163
# Epoch 17/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160
# Epoch 18/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0166
# Epoch 19/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168
# Epoch 20/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0163
# Epoch 21/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0177
# Epoch 22/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0174
# Epoch 23/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0161
# Epoch 24/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0160
# Epoch 25/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0170
# Epoch 26/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169
# Epoch 27/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0173
# Epoch 28/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169
# Epoch 29/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0158
# Epoch 30/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0180
# Epoch 31/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168
# Epoch 32/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0179
# Epoch 33/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166
# Epoch 34/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174
# Epoch 35/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178
# Epoch 36/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173
# Epoch 37/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0164
# Epoch 38/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 703us/step - loss: 0.0167
# Epoch 39/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0164
# Epoch 40/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0179
# Epoch 41/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169
# Epoch 42/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168
# Epoch 43/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164
# Epoch 44/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0170
# Epoch 45/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0160
# Epoch 46/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 0.0163
# Epoch 47/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0177
# Epoch 48/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168
# Epoch 49/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181
# Epoch 50/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0173
# Test MSE: 0.01697290688753128
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# R^2 Score: 0.3246
# MAE: 5.275401749836164e-05
# Test MSE: 4.752588794724244e-09

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Load the dataset
df = pd.read_csv(r"..\processed data\all_data_combined.csv")
df = df[df['Location'] == 'Colombo Proper']

# Define columns to keep
columns_to_keep = ['Current_Date', 'HCHO_reading', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 
                   'Population_density', 'total', 'new', 'Lockdown', 'carbonmonoxide_average', 
                   'nitrogendioxide_average', 'ozone_average']

df = df[columns_to_keep]

# Convert 'Current_Date' to DateTime format
df['Current_Date'] = pd.to_datetime(df['Current_Date'])

# Sort by date and set index
df = df.sort_values(by='Current_Date')
df.set_index('Current_Date', inplace=True)

# Define input features (X) and target variable (y)
X_cols = ['TMAX', 'TMIN','carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average']
y_col = ['HCHO_reading']

X = df[X_cols]  # Features
y = df[y_col]   # Target

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape input data to 3D array (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Define the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Train the model and capture history
history = model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_data=(X_test, y_test))

# Plot loss curve
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# C:\Users\janak\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1657 - val_loss: 0.0271
# Epoch 2/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0241 - val_loss: 0.0230
# Epoch 3/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0225 - val_loss: 0.0214
# Epoch 4/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0192 - val_loss: 0.0201
# Epoch 5/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - val_loss: 0.0192
# Epoch 6/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0184
# Epoch 7/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - val_loss: 0.0180
# Epoch 8/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160 - val_loss: 0.0178
# Epoch 9/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170 - val_loss: 0.0177
# Epoch 10/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - val_loss: 0.0178
# Epoch 11/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - val_loss: 0.0175
# Epoch 12/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174 - val_loss: 0.0174
# Epoch 13/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - val_loss: 0.0173
# Epoch 14/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0158 - val_loss: 0.0173
# Epoch 15/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0167 - val_loss: 0.0174
# Epoch 16/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0167 - val_loss: 0.0173
# Epoch 17/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167 - val_loss: 0.0172
# Epoch 18/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0165 - val_loss: 0.0172
# Epoch 19/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0165 - val_loss: 0.0175
# Epoch 20/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164 - val_loss: 0.0176
# Epoch 21/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164 - val_loss: 0.0172
# Epoch 22/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - val_loss: 0.0171
# Epoch 23/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167 - val_loss: 0.0173
# Epoch 24/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171 - val_loss: 0.0172
# Epoch 25/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171 - val_loss: 0.0171
# Epoch 26/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0170 - val_loss: 0.0171
# Epoch 27/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0180 - val_loss: 0.0171
# Epoch 28/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - val_loss: 0.0172
# Epoch 29/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - val_loss: 0.0170
# Epoch 30/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - val_loss: 0.0171
# Epoch 31/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0170 - val_loss: 0.0171
# Epoch 32/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0175 - val_loss: 0.0173
# Epoch 33/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0169 - val_loss: 0.0171
# Epoch 34/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169 - val_loss: 0.0173
# Epoch 35/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169 - val_loss: 0.0171
# Epoch 36/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0176 - val_loss: 0.0170
# Epoch 37/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0172 - val_loss: 0.0170
# Epoch 38/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166 - val_loss: 0.0170
# Epoch 39/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0155 - val_loss: 0.0172
# Epoch 40/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - val_loss: 0.0172
# Epoch 41/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163 - val_loss: 0.0170
# Epoch 42/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0156 - val_loss: 0.0170
# Epoch 43/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0158 - val_loss: 0.0171
# Epoch 44/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - val_loss: 0.0170
# Epoch 45/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0164 - val_loss: 0.0170
# Epoch 46/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0170
# Epoch 47/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0182 - val_loss: 0.0174
# Epoch 48/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167 - val_loss: 0.0171
# Epoch 49/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0157 - val_loss: 0.0172
# Epoch 50/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0173 - val_loss: 0.0170

# %%
# Evaluate the model
mse = model.evaluate(X_test, y_test, verbose=0)
print("Test MSE:", mse)

import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error,mean_squared_error

# Predictions on test data
y_pred = model.predict(X_test)

# Rescale predictions and actuals
y_pred_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_pred), axis=1))
y_test_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_test.reshape(-1, 1)), axis=1))

# Extract the HCHO readings
y_pred_hcho = y_pred_rescaled[:, -1]
y_test_hcho = y_test_rescaled[:, -1]

# Calculate R^2 score and MAE
r2 = round(r2_score(y_test_hcho, y_pred_hcho), 4)
mae = mean_absolute_error(y_test_hcho, y_pred_hcho)
mse = mean_squared_error(y_test_hcho, y_pred_hcho)
print("R^2 Score:", r2)
print("MAE:", mae)
print("Test MSE:", mse)

# Plot predictions vs actuals
plt.figure(figsize=(10, 6))
plt.plot(df.index[-len(y_test_hcho):], y_test_hcho, label='Actuals', color='blue')
plt.plot(df.index[-len(y_pred_hcho):], y_pred_hcho, label='Predictions', color='red', linestyle='--')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.title('Actual vs Predicted HCHO Readings')
plt.legend()
plt.show()
# Out:
# Test MSE: 0.016983769834041595
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# R^2 Score: 0.3243
# MAE: 5.265238674002843e-05
# Test MSE: 4.755155285917351e-09

# %%
# Best

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Load the dataset
df = pd.read_csv(r"..\processed data\all_data_combined.csv")
df = df[df['Location'] == 'Colombo Proper']

# Define columns to keep
columns_to_keep = ['Current_Date', 'HCHO_reading', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 
                   'Population_density', 'total', 'new', 'Lockdown', 'carbonmonoxide_average', 
                   'nitrogendioxide_average', 'ozone_average']

df = df[columns_to_keep]

# Convert 'Current_Date' to DateTime format
df['Current_Date'] = pd.to_datetime(df['Current_Date'])

# Sort by date and set index
df = df.sort_values(by='Current_Date')
df.set_index('Current_Date', inplace=True)

# Define input features (X) and target variable (y)
X_cols = ['TMAX', 'TMIN','carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average']
y_col = ['HCHO_reading']

X = df[X_cols]  # Features
y = df[y_col]   # Target

scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# Reshape input data to 3D array (samples, timesteps, features)
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Define the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Train the model and capture history
history = model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1, validation_data=(X_test, y_test))

# Plot loss curve
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# Predictions on test data
y_pred = model.predict(X_test)

# Rescale predictions and actuals
y_pred_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_pred), axis=1))
y_test_rescaled = scaler.inverse_transform(np.concatenate((X_test.reshape(X_test.shape[0], -1)[:, :-1], y_test.reshape(-1, 1)), axis=1))

# Extract the HCHO readings
y_pred_hcho = y_pred_rescaled[:, -1]
y_test_hcho = y_test_rescaled[:, -1]

# Calculate R^2 score and MAE
r2 = round(r2_score(y_test_hcho, y_pred_hcho), 4)
mae = mean_absolute_error(y_test_hcho, y_pred_hcho)
mse = mean_squared_error(y_test_hcho, y_pred_hcho)
print("R^2 Score:", r2)
print("MAE:", mae)
print("Test MSE:", mse)

# Plot predictions vs actuals
plt.figure(figsize=(10, 6))
plt.plot(df.index[-len(y_test_hcho):], y_test_hcho, label='Actuals', color='blue')
plt.plot(df.index[-len(y_pred_hcho):], y_pred_hcho, label='Predictions', color='red', linestyle='--')
plt.xlabel('Date')
plt.ylabel('HCHO Reading')
plt.title('Actual vs Predicted HCHO Readings')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# C:\Users\janak\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.1874 - val_loss: 0.0292
# Epoch 2/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0255 - val_loss: 0.0231
# Epoch 3/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0226 - val_loss: 0.0213
# Epoch 4/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0204 - val_loss: 0.0199
# Epoch 5/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202 - val_loss: 0.0189
# Epoch 6/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - val_loss: 0.0181
# Epoch 7/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - val_loss: 0.0177
# Epoch 8/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0179 - val_loss: 0.0175
# Epoch 9/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0178 - val_loss: 0.0173
# Epoch 10/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174 - val_loss: 0.0173
# Epoch 11/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0161 - val_loss: 0.0173
# Epoch 12/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0161 - val_loss: 0.0172
# Epoch 13/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - val_loss: 0.0172
# Epoch 14/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0183 - val_loss: 0.0172
# Epoch 15/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0171
# Epoch 16/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - val_loss: 0.0171
# Epoch 17/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0165 - val_loss: 0.0171
# Epoch 18/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170 - val_loss: 0.0171
# Epoch 19/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0158 - val_loss: 0.0170
# Epoch 20/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0163 - val_loss: 0.0170
# Epoch 21/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0175 - val_loss: 0.0174
# Epoch 22/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167 - val_loss: 0.0171
# Epoch 23/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0160 - val_loss: 0.0172
# Epoch 24/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0165 - val_loss: 0.0170
# Epoch 25/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0175 - val_loss: 0.0170
# Epoch 26/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0165 - val_loss: 0.0171
# Epoch 27/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0165 - val_loss: 0.0170
# Epoch 28/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174 - val_loss: 0.0174
# Epoch 29/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0168 - val_loss: 0.0170
# Epoch 30/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0172 - val_loss: 0.0171
# Epoch 31/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0165 - val_loss: 0.0170
# Epoch 32/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0171 - val_loss: 0.0173
# Epoch 33/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0175 - val_loss: 0.0170
# Epoch 34/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0165 - val_loss: 0.0174
# Epoch 35/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0160 - val_loss: 0.0172
# Epoch 36/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0168 - val_loss: 0.0170
# Epoch 37/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0172 - val_loss: 0.0170
# Epoch 38/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0171 - val_loss: 0.0170
# Epoch 39/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0176 - val_loss: 0.0170
# Epoch 40/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0171 - val_loss: 0.0170
# Epoch 41/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0170 - val_loss: 0.0171
# Epoch 42/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0174 - val_loss: 0.0171
# Epoch 43/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0188 - val_loss: 0.0173
# Epoch 44/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0167 - val_loss: 0.0171
# Epoch 45/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0164 - val_loss: 0.0170
# Epoch 46/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0164 - val_loss: 0.0170
# Epoch 47/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0166 - val_loss: 0.0170
# Epoch 48/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0161 - val_loss: 0.0170
# Epoch 49/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - val_loss: 0.0170
# Epoch 50/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0168 - val_loss: 0.0170
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# R^2 Score: 0.3212
# MAE: 5.2635117982565605e-05
# Test MSE: 4.776913251390785e-09

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Load the dataset
df = pd.read_csv(r"..\processed data\all_data_combined.csv")
df = df[df['Location'] == 'Colombo Proper']

# Define columns to keep
columns_to_keep = ['Current_Date', 'HCHO_reading', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 
                   'Population_density', 'total', 'new', 'Lockdown', 'carbonmonoxide_average', 
                   'nitrogendioxide_average', 'ozone_average']

df = df[columns_to_keep]

# Convert 'Current_Date' to DateTime format
df['Current_Date'] = pd.to_datetime(df['Current_Date'])

# Sort by date and set index
df = df.sort_values(by='Current_Date')
df.set_index('Current_Date', inplace=True)

# Define input features (X) and target variable (y)
X_cols = ['TMAX', 'TMIN','carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average']
y_col = ['HCHO_reading']

X = df[X_cols].values  # Features
y = df[y_col].values   # Target

# Normalize the data
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Define train and test data
train_size = int(len(X_scaled) * 0.8)
test_size = len(X_scaled) - train_size
X_train, X_test = X_scaled[0:train_size,:], X_scaled[train_size:len(X_scaled),:]
y_train, y_test = y_scaled[0:train_size,:], y_scaled[train_size:len(y_scaled),:]

# Define function to create sequences
def create_sequences(X, y, time_steps=1):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i:(i + time_steps)])
        y_seq.append(y[i + time_steps])
    return np.array(X_seq), np.array(y_seq)

# Define the time steps
time_steps = 2  # You can adjust this as needed

# Create sequences
X_train_seq, y_train_seq = create_sequences(X_train, y_train, time_steps)
X_test_seq, y_test_seq = create_sequences(X_test, y_test, time_steps)

# Define the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Define early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True)

# Fit the model
history = model.fit(X_train_seq, y_train_seq, epochs=50, batch_size=32, validation_data=(X_test_seq, y_test_seq), callbacks=[early_stopping], verbose=1)

# Plot training loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Predict on test data
y_pred = model.predict(X_test_seq)

# Inverse transform to get original values
y_pred_inv = scaler_y.inverse_transform(y_pred)
y_test_inv = scaler_y.inverse_transform(y_test_seq)

# Calculate evaluation metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
r2 = r2_score(y_test_inv, y_pred_inv)
print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared Score (R2): {r2}')

# Plot actual vs predicted
plt.figure(figsize=(10, 6))
plt.plot(df.index[-len(y_test_inv):],y_test_inv, label='Actual')
plt.plot(df.index[-len(y_test_inv):],y_pred_inv, label='Predicted')
plt.title('Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# C:\Users\janak\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1310 - val_loss: 0.0244
# Epoch 2/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0237 - val_loss: 0.0210
# Epoch 3/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0190 - val_loss: 0.0192
# Epoch 4/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189 - val_loss: 0.0188
# Epoch 5/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - val_loss: 0.0188
# Epoch 6/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0183 - val_loss: 0.0192
# Epoch 7/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0172 - val_loss: 0.0187
# Epoch 8/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0192 - val_loss: 0.0186
# Epoch 9/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0188 - val_loss: 0.0186
# Epoch 10/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0195 - val_loss: 0.0186
# Epoch 11/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175 - val_loss: 0.0186
# Epoch 12/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0183 - val_loss: 0.0186
# Epoch 13/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - val_loss: 0.0190
# Epoch 14/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0184 - val_loss: 0.0185
# Epoch 15/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0186 - val_loss: 0.0197
# Epoch 16/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - val_loss: 0.0193
# Epoch 17/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0190 - val_loss: 0.0185
# Epoch 18/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0177 - val_loss: 0.0187
# Epoch 19/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - val_loss: 0.0185
# Epoch 20/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0180 - val_loss: 0.0185
# Epoch 21/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0178 - val_loss: 0.0190
# Epoch 22/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - val_loss: 0.0187
# Epoch 23/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0187 - val_loss: 0.0186
# Epoch 24/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0185 - val_loss: 0.0184
# Epoch 25/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0179 - val_loss: 0.0188
# Epoch 26/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0179 - val_loss: 0.0187
# Epoch 27/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0177 - val_loss: 0.0185
# Epoch 28/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0183 - val_loss: 0.0189
# Epoch 29/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191 - val_loss: 0.0186
# Epoch 30/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 31/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - val_loss: 0.0186
# Epoch 32/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0184 - val_loss: 0.0188
# Epoch 33/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0180 - val_loss: 0.0186
# Epoch 34/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184 - val_loss: 0.0184
# Epoch 35/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0167 - val_loss: 0.0185
# Epoch 36/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 37/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0187 - val_loss: 0.0185
# Epoch 38/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0189 - val_loss: 0.0194
# Epoch 39/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0192 - val_loss: 0.0184
# Epoch 40/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0176 - val_loss: 0.0185
# Epoch 41/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0190 - val_loss: 0.0184
# Epoch 42/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0210 - val_loss: 0.0186
# Epoch 43/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0188 - val_loss: 0.0185
# Epoch 44/50
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0185 - val_loss: 0.0185
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 34.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Mean Squared Error (MSE): 5.100432656624761e-09
# Mean Absolute Error (MAE): 5.453053072040999e-05
# R-squared Score (R2): 0.27467488724872624

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Load the dataset
df = pd.read_csv(r"..\processed data\all_data_combined.csv")
df = df[df['Location'] == 'Colombo Proper']

# Define columns to keep
columns_to_keep = ['Current_Date', 'HCHO_reading', 'PRCP', 'TAVG', 'TMAX', 'TMIN', 'Population', 
                   'Population_density', 'total', 'new', 'Lockdown', 'carbonmonoxide_average', 
                   'nitrogendioxide_average', 'ozone_average']

df = df[columns_to_keep]

# Convert 'Current_Date' to DateTime format
df['Current_Date'] = pd.to_datetime(df['Current_Date'])

# Sort by date and set index
df = df.sort_values(by='Current_Date')
df.set_index('Current_Date', inplace=True)

# Define input features (X) and target variable (y)
X_cols = ['TMAX', 'TMIN','carbonmonoxide_average', 'nitrogendioxide_average', 'ozone_average']
y_col = ['HCHO_reading']

X = df[X_cols].values  # Features
y = df[y_col].values   # Target

# Normalize the data
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Define train and test data
train_size = int(len(X_scaled) * 0.8)
test_size = len(X_scaled) - train_size
X_train, X_test = X_scaled[0:train_size,:], X_scaled[train_size:len(X_scaled),:]
y_train, y_test = y_scaled[0:train_size,:], y_scaled[train_size:len(y_scaled),:]

# Define function to create sequences
def create_sequences(X, y, time_steps=1):
    X_seq, y_seq = [], []
    for i in range(len(X) - time_steps):
        X_seq.append(X[i:(i + time_steps)])
        y_seq.append(y[i + time_steps])
    return np.array(X_seq), np.array(y_seq)

# Define the time steps
time_steps = 2  # You can adjust this as needed

# Create sequences
X_train_seq, y_train_seq = create_sequences(X_train, y_train, time_steps)
X_test_seq, y_test_seq = create_sequences(X_test, y_test, time_steps)

# # Define the LSTM model
# model = Sequential()
# model.add(LSTM(50, input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam')

# Define the LSTM model with activation functions
model = Sequential([
    LSTM(100, input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]), return_sequences=True, activation='relu'),
    LSTM(50, return_sequences=True, activation='relu'),
    LSTM(50, activation='relu'),
    Dense(1, activation='linear')
])
model.compile(loss='mean_squared_error', optimizer='adam')

# Define early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min', restore_best_weights=True)

# Fit the model
history = model.fit(X_train_seq, y_train_seq, epochs=50, batch_size=20, validation_data=(X_test_seq, y_test_seq), callbacks=[early_stopping], verbose=1)

# Plot training loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Predict on test data
y_pred = model.predict(X_test_seq)

# Inverse transform to get original values
y_pred_inv = scaler_y.inverse_transform(y_pred)
y_test_inv = scaler_y.inverse_transform(y_test_seq)

# Calculate evaluation metrics
mse = mean_squared_error(y_test_inv, y_pred_inv)
mae = mean_absolute_error(y_test_inv, y_pred_inv)
r2 = r2_score(y_test_inv, y_pred_inv)
print(f'Mean Squared Error (MSE): {mse}')
print(f'Mean Absolute Error (MAE): {mae}')
print(f'R-squared Score (R2): {r2}')

# Plot actual vs predicted
plt.figure(figsize=(10, 6))
plt.plot(df.index[-len(y_test_inv):],y_test_inv, label='Actual')
plt.plot(df.index[-len(y_test_inv):],y_pred_inv, label='Predicted')
plt.title('Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('HCHO Reading')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# C:\Users\janak\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.1857 - val_loss: 0.0262
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0208 - val_loss: 0.0194
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0193 - val_loss: 0.0215
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0183 - val_loss: 0.0189
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0195 - val_loss: 0.0189
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0187 - val_loss: 0.0190
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0191 - val_loss: 0.0187
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0187 - val_loss: 0.0189
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0163 - val_loss: 0.0186
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174 - val_loss: 0.0199
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188 - val_loss: 0.0192
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0182 - val_loss: 0.0185
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0186 - val_loss: 0.0185
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0189 - val_loss: 0.0185
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181 - val_loss: 0.0189
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0190 - val_loss: 0.0188
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0179 - val_loss: 0.0191
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0201 - val_loss: 0.0185
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196 - val_loss: 0.0184
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178 - val_loss: 0.0187
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0188 - val_loss: 0.0185
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - val_loss: 0.0187
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0192 - val_loss: 0.0204
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.0166 - val_loss: 0.0184
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0187 - val_loss: 0.0184
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0195 - val_loss: 0.0185
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0183 - val_loss: 0.0184
# Epoch 28/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0186 - val_loss: 0.0184
# Epoch 29/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0178 - val_loss: 0.0191
# Epoch 30/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0201 - val_loss: 0.0190
# Epoch 31/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0193 - val_loss: 0.0185
# Epoch 32/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0183 - val_loss: 0.0184
# Epoch 33/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - val_loss: 0.0184
# Epoch 34/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0178 - val_loss: 0.0186
# Epoch 35/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0170 - val_loss: 0.0187
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 25.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step
# Mean Squared Error (MSE): 5.106182913427949e-09
# Mean Absolute Error (MAE): 5.489024307993383e-05
# R-squared Score (R2): 0.2738571515888497
