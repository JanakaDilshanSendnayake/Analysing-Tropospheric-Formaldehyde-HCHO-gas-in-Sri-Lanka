# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
import numpy as np
# Set the style to 'whitegrid'
plt.style.use('seaborn-whitegrid')
# Out:
# C:\Users\janak\AppData\Local\Temp\ipykernel_19268\3836125493.py:7: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # Covid data analysis

# %% [markdown]
# ## API

# %%
import requests

country = 'Sri Lanka'
region='galle'
api_url = 'https://api.api-ninjas.com/v1/covid19?country={}'.format(country,region)
response = requests.get(api_url, headers={'X-Api-Key': 'ChFX2bim+4wKPTz29XhdDA==AnPaGTh554GAAJiB'})
if response.status_code == requests.codes.ok:
    print(response.text)
    print(type(response.text))
else:
    print("Error:", response.status_code, response.text)
# Out:
# [{"country": "Sri Lanka", "region": "", "cases": {"2020-01-22": {"total": 0, "new": 0}, "2020-01-23": {"total": 0, "new": 0}, "2020-01-24": {"total": 0, "new": 0}, "2020-01-25": {"total": 0, "new": 0}, "2020-01-26": {"total": 0, "new": 0}, "2020-01-27": {"total": 1, "new": 1}, "2020-01-28": {"total": 1, "new": 0}, "2020-01-29": {"total": 1, "new": 0}, "2020-01-30": {"total": 1, "new": 0}, "2020-01-31": {"total": 1, "new": 0}, "2020-02-01": {"total": 1, "new": 0}, "2020-02-02": {"total": 1, "new": 0}, "2020-02-03": {"total": 1, "new": 0}, "2020-02-04": {"total": 1, "new": 0}, "2020-02-05": {"total": 1, "new": 0}, "2020-02-06": {"total": 1, "new": 0}, "2020-02-07": {"total": 1, "new": 0}, "2020-02-08": {"total": 1, "new": 0}, "2020-02-09": {"total": 1, "new": 0}, "2020-02-10": {"total": 1, "new": 0}, "2020-02-11": {"total": 1, "new": 0}, "2020-02-12": {"total": 1, "new": 0}, "2020-02-13": {"total": 1, "new": 0}, "2020-02-14": {"total": 1, "new": 0}, "2020-02-15": {"total": 1, "new": 0}, "2020-02-16": {"total": 1, "new": 0}, "2020-02-17": {"total": 1, "new": 0}, "2020-02-18": {"total": 1, "new": 0}, "2020-02-19": {"total": 1, "new": 0}, "2020-02-20": {"total": 1, "new": 0}, "2020-02-21": {"total": 1, "new": 0}, "2020-02-22": {"total": 1, "new": 0}, "2020-02-23": {"total": 1, "new": 0}, "2020-02-24": {"total": 1, "new": 0}, "2020-02-25": {"total": 1, "new": 0}, "2020-02-26": {"total": 1, "new": 0}, "2020-02-27": {"total": 1, "new": 0}, "2020-02-28": {"total": 1, "new": 0}, "2020-02-29": {"total": 1, "new": 0}, "2020-03-01": {"total": 1, "new": 0}, "2020-03-02": {"total": 1, "new": 0}, "2020-03-03": {"total": 1, "new": 0}, "2020-03-04": {"total": 1, "new": 0}, "2020-03-05": {"total": 1, "new": 0}, "2020-03-06": {"total": 1, "new": 0}, "2020-03-07": {"total": 1, "new": 0}, "2020-03-08": {"total": 1, "new": 0}, "2020-03-09": {"total": 1, "new": 0}, "2020-03-10": {"total": 1, "new": 0}, "2020-03-11": {"total": 2, "new": 1}, "2020-03-12": {"total": 2, "new": 0}, "2020-03-13": {"total": 6, "new": 4}, "2020-03-14": {"total": 10, "new": 4}, "2020-03-15": {"total": 18, "new": 8}, "2020-03-16": {"total": 28, "new": 10}, "2020-03-17": {"total": 44, "new": 16}, "2020-03-18": {"total": 51, "new": 7}, "2020-03-19": {"total": 60, "new": 9}, "2020-03-20": {"total": 73, "new": 13}, "2020-03-21": {"total": 77, "new": 4}, "2020-03-22": {"total": 82, "new": 5}, "2020-03-23": {"total": 97, "new": 15}, "2020-03-24": {"total": 102, "new": 5}, "2020-03-25": {"total": 102, "new": 0}, "2020-03-26": {"total": 106, "new": 4}, "2020-03-27": {"total": 106, "new": 0}, "2020-03-28": {"total": 113, "new": 7}, "2020-03-29": {"total": 117, "new": 4}, "2020-03-30": {"total": 122, "new": 5}, "2020-03-31": {"total": 143, "new": 21}, "2020-04-01": {"total": 146, "new": 3}, "2020-04-02": {"total": 151, "new": 5}, "2020-04-03": {"total": 159, "new": 8}, "2020-04-04": {"total": 166, "new": 7}, "2020-04-05": {"total": 176, "new": 10}, "2020-04-06": {"total": 178, "new": 2}, "2020-04-07": {"total": 185, "new": 7}, "2020-04-08": {"total": 189, "new": 4}, "2020-04-09": {"total": 190, "new": 1}, "2020-04-10": {"total": 190, "new": 0}, "2020-04-11": {"total": 198, "new": 8}, "2020-04-12": {"total": 210, "new": 12}, "2020-04-13": {"total": 217, "new": 7}, "2020-04-14": {"total": 233, "new": 16}, "2020-04-15": {"total": 238, "new": 5}, "2020-04-16": {"total": 238, "new": 0}, "2020-04-17": {"total": 244, "new": 6}, "2020-04-18": {"total": 254, "new": 10}, "2020-04-19": {"total": 271, "new": 17}, "2020-04-20": {"total": 304, "new": 33}, "2020-04-21": {"total": 310, "new": 6}, "2020-04-22": {"total": 330, "new": 20}, "2020-04-23": {"total": 368, "new": 38}, "2020-04-24": {"total": 420, "new": 52}, "2020-04-25": {"total": 460, "new": 40}, "2020-04-26": {"total": 523, "new": 63}, "2020-04-27": {"total": 588, "new": 65}, "2020-04-28": {"total": 619, "new": 31}, "2020-04-29": {"total": 649, "new": 30}, "2020-04-30": {"total": 663, "new": 14}, "2020-05-01": {"total": 690, "new": 27}, "20 ...
# <class 'str'>

# %%
import json

# API response content
response_content = response.text
# Convert response content to JSON
data = json.loads(response_content)

# Create DataFrame directly
df = pd.DataFrame(data[0]['cases']).T.reset_index()
df = df.rename(columns={'index': 'date'})

# Add country and region columns
df['country'] = data[0]['country']
df['region'] = data[0]['region']

# Reorder columns
df = df[['country', 'region', 'date', 'total', 'new']]

# Print DataFrame
df.tail(10)
# Out:
#         country region        date   total  new
# 1133  Sri Lanka         2023-02-28  672030    1
# 1134  Sri Lanka         2023-03-01  672031    1
# 1135  Sri Lanka         2023-03-02  672031    0
# 1136  Sri Lanka         2023-03-03  672032    1
# 1137  Sri Lanka         2023-03-04  672032    0
# 1138  Sri Lanka         2023-03-05  672034    2
# 1139  Sri Lanka         2023-03-06  672034    0
# 1140  Sri Lanka         2023-03-07  672036    2
# 1141  Sri Lanka         2023-03-08  672037    1
# 1142  Sri Lanka         2023-03-09  672039    2

# %%
df[['country','region']].value_counts()
# Out:
# country    region
# Sri Lanka            1143
# Name: count, dtype: int64

# %%
df.drop(columns=['region', 'country'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1143 non-null   object
#  1   total   1143 non-null   int64
#  2   new     1143 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 26.9+ KB

# %%
try:
    # Convert 'Current_Date' to DateTime format
    df['date'] = pd.to_datetime(df['date'])
    print("Conversion to DateTime format successful.")
except ValueError as e:
    print(f"Error converting to DateTime format: {e}")
# Out:
# Conversion to DateTime format successful.

# %%
df.describe()
# Out:
#                       date          total          new
# count                 1143    1143.000000   1143.00000
# mean   2021-08-15 00:00:00  345019.684164    587.96063
# min    2020-01-22 00:00:00       0.000000      0.00000
# 25%    2020-11-02 12:00:00   11539.500000      8.00000
# 50%    2021-08-15 00:00:00  354968.000000     99.00000
# 75%    2022-05-27 12:00:00  663808.000000    719.00000
# max    2023-03-09 00:00:00  672039.000000  11366.00000
# std                    NaN  292757.607554   1064.34241

# %%
# Step 1: Check Time Range
min_date = '2019-01-01'
max_date = '2024-01-01'
print("Time Range: From", min_date, "to", max_date)

# Step 2: Generate Time Range
complete_time_range = pd.date_range(start=min_date, end=max_date, freq='D')  
# Step 3: Identify Missing Values
missing_values = complete_time_range[~complete_time_range.isin(df['date'])]

if len(missing_values) == 0:
    print("No missing dates found in the time range.")
else:
    print("Missing dates found:")
    print('Count: ',len(missing_values))
    print(missing_values)
# Out:
# Time Range: From 2019-01-01 to 2024-01-01
# Missing dates found:
# Count:  684
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2023-12-23', '2023-12-24', '2023-12-25', '2023-12-26',
#                '2023-12-27', '2023-12-28', '2023-12-29', '2023-12-30',
#                '2023-12-31', '2024-01-01'],
#               dtype='datetime64[ns]', length=684, freq=None)

# %%
# Step 4: Create DataFrame for missing dates
missing_df = pd.DataFrame({'date': missing_values})

# Step 5: Concatenate missing dates DataFrame with existing DataFrame
df = pd.concat([df, missing_df], ignore_index=True)

# Sort the DataFrame by 'DATE' column
df = df.sort_values(by='date')
df = df.reset_index(drop=True)

print("Missing dates added:")
df[df['date'].isin(missing_values)]
# Out:
# Missing dates added:
#            date  total  new
# 0    2019-01-01    NaN  NaN
# 1    2019-01-02    NaN  NaN
# 2    2019-01-03    NaN  NaN
# 3    2019-01-04    NaN  NaN
# 4    2019-01-05    NaN  NaN
# ...         ...    ...  ...
# 1822 2023-12-28    NaN  NaN
# 1823 2023-12-29    NaN  NaN
# 1824 2023-12-30    NaN  NaN
# 1825 2023-12-31    NaN  NaN
# 1826 2024-01-01    NaN  NaN
#
# [684 rows x 3 columns]

# %%
df['new']=df['new'].fillna(0)
df.loc[df['date'] > pd.to_datetime('2023-03-09'), 'total'] = df.loc[df['date'] > pd.to_datetime('2023-03-09'), 'total'].fillna(df['total'].max())
df.loc[df['date'] < pd.to_datetime('2020-01-22'), 'total'] = df.loc[df['date'] < pd.to_datetime('2020-01-22'), 'total'].fillna(df['total'].min())

# %%
df.isnull().sum()
# Out:
# date     0
# total    0
# new      0
# dtype: int64

# %%
# Create the plot
plt.figure(figsize=(20, 6))
plt.plot( df['date'], df["total"], label="HCHO_reading")
plt.title("Total cases visualization")
plt.xlabel("Date")
plt.ylabel("Total cases")
plt.legend()
plt.show()

# %%
# Create the plot
plt.figure(figsize=(20, 6))
plt.plot( df['date'], df["new"], label="HCHO_reading")
plt.title("New cases visualization")
plt.xlabel("Date")
plt.ylabel("New cases")
plt.legend()
plt.show()

# %%
df.head(20)
# Out:
#          date  total  new
# 0  2019-01-01    0.0  0.0
# 1  2019-01-02    0.0  0.0
# 2  2019-01-03    0.0  0.0
# 3  2019-01-04    0.0  0.0
# 4  2019-01-05    0.0  0.0
# 5  2019-01-06    0.0  0.0
# 6  2019-01-07    0.0  0.0
# 7  2019-01-08    0.0  0.0
# 8  2019-01-09    0.0  0.0
# 9  2019-01-10    0.0  0.0
# 10 2019-01-11    0.0  0.0
# 11 2019-01-12    0.0  0.0
# 12 2019-01-13    0.0  0.0
# 13 2019-01-14    0.0  0.0
# 14 2019-01-15    0.0  0.0
# 15 2019-01-16    0.0  0.0
# 16 2019-01-17    0.0  0.0
# 17 2019-01-18    0.0  0.0
# 18 2019-01-19    0.0  0.0
# 19 2019-01-20    0.0  0.0

# %% [markdown]
# # Population data

# %%
population= pd.read_csv('raw_data\population.csv')
population
# Out:
#         District   2017   2018   2019   2020   2021   2022   2023
# 0        Colombo  2,419  2,439  2,448  2,455  2,480  2,478  2,460
# 1        Gampaha  2,391  2,409  2,417  2,423  2,443  2,439  2,421
# 2       Kalutara  1,271  1,281  1,284  1,287  1,296  1,292  1,279
# 3          Kandy  1,452  1,468  1,476  1,483  1,501  1,499  1,482
# 4         Matale    514    519    522    525    530    530    525
# 5   Nuwara-eliya    756    763    768    773    780    783    781
# 6          Galle  1,113  1,124  1,130  1,135  1,147  1,147  1,139
# 7         Matara    851    858    863    866    873    874    869
# 8     Hambantota    647    655    661    668    676    681    680
# 9         Jaffna    608    613    617    621    626    629    628
# 10   Kilinochchi    124    126    129    130    133    135    136
# 11        Mannar    107    109    111    112    114    115    116
# 12      Vavuniya    184    187    189    191    194    195    196
# 13    Mullaitivu     96     96     97     98     98     99     99
# 14    Batticaloa    560    570    575    579    590    590    582
# 15        Ampara    705    719    728    736    752    754    749
# 16   Trincomalee    412    421    426    431    441    444    443
# 17    Kurunegala  1,694  1,711  1,719  1,726  1,743  1,742  1,727
# 18      Puttalam    814    825    832    837    849    850    845
# 19  Anuradhapura    918    930    937    943    954    957    950
# 20   Polonnaruwa    431    436    440    443    448    449    445
# 21       Badulla    864    873    880    886    895    899    896
# 22    Monaragala    485    491    496    501    505    509    509
# 23     Ratnapura  1,151  1,163  1,171  1,179  1,190  1,193  1,188
# 24       Kegalle    877    884    887    891    898    898    892

# %%
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   District  25 non-null     object
#  1   2017      25 non-null     object
#  2   2018      25 non-null     object
#  3   2019      25 non-null     object
#  4   2020      25 non-null     object
#  5   2021      25 non-null     object
#  6   2022      25 non-null     object
#  7   2023      25 non-null     object
# dtypes: object(8)
# memory usage: 1.7+ KB

# %%
population.drop(columns=['2017','2018'],inplace=True)

# %%
districts_to_keep=['Colombo','Kandy','Nuwara-eliya', 'Matara','Monaragala','Jaffna','Kurunegala']
population=population[population['District'].isin(districts_to_keep)]
population
# Out:
#         District   2019   2020   2021   2022   2023
# 0        Colombo  2,448  2,455  2,480  2,478  2,460
# 3          Kandy  1,476  1,483  1,501  1,499  1,482
# 5   Nuwara-eliya    768    773    780    783    781
# 7         Matara    863    866    873    874    869
# 9         Jaffna    617    621    626    629    628
# 17    Kurunegala  1,719  1,726  1,743  1,742  1,727
# 22    Monaragala    496    501    505    509    509

# %%
replacement_mapping = {'Colombo': 'Colombo Proper', 
                       'Kandy': 'Kandy Proper',
                       'Nuwara-eliya':'Nuwara Eliya Proper',
                       'Matara':'Deniyaya, Matara',
                       'Jaffna':'Jaffna Proper',
                       'Kurunegala':'Kurunegala Proper',
                       'Monaragala':'Bibile, Monaragala'}

population['District'] = population['District'].replace(replacement_mapping)
# Out:
# C:\Users\janak\AppData\Local\Temp\ipykernel_19268\2035344545.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   population['District'] = population['District'].replace(replacement_mapping)

# %%
population = population.melt(id_vars='District', var_name='Year', value_name='Population')
population = population.sort_values(by=['District','Year'])
population
# Out:
#                District  Year Population
# 6    Bibile, Monaragala  2019        496
# 13   Bibile, Monaragala  2020        501
# 20   Bibile, Monaragala  2021        505
# 27   Bibile, Monaragala  2022        509
# 34   Bibile, Monaragala  2023        509
# 0        Colombo Proper  2019      2,448
# 7        Colombo Proper  2020      2,455
# 14       Colombo Proper  2021      2,480
# 21       Colombo Proper  2022      2,478
# 28       Colombo Proper  2023      2,460
# 3      Deniyaya, Matara  2019        863
# 10     Deniyaya, Matara  2020        866
# 17     Deniyaya, Matara  2021        873
# 24     Deniyaya, Matara  2022        874
# 31     Deniyaya, Matara  2023        869
# 4         Jaffna Proper  2019        617
# 11        Jaffna Proper  2020        621
# 18        Jaffna Proper  2021        626
# 25        Jaffna Proper  2022        629
# 32        Jaffna Proper  2023        628
# 1          Kandy Proper  2019      1,476
# 8          Kandy Proper  2020      1,483
# 15         Kandy Proper  2021      1,501
# 22         Kandy Proper  2022      1,499
# 29         Kandy Proper  2023      1,482
# 5     Kurunegala Proper  2019      1,719
# 12    Kurunegala Proper  2020      1,726
# 19    Kurunegala Proper  2021      1,743
# 26    Kurunegala Proper  2022      1,742
# 33    Kurunegala Proper  2023      1,727
# 2   Nuwara Eliya Proper  2019        768
# 9   Nuwara Eliya Proper  2020        773
# 16  Nuwara Eliya Proper  2021        780
# 23  Nuwara Eliya Proper  2022        783
# 30  Nuwara Eliya Proper  2023        781

# %%
population['Population'] = population['Population'].str.replace(',', '').astype(int)*1000
population['Year']=population['Year'].astype(int)
population.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35 entries, 6 to 30
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   District    35 non-null     object
#  1   Year        35 non-null     int32
#  2   Population  35 non-null     int32
# dtypes: int32(2), object(1)
# memory usage: 840.0+ bytes

# %%
areas=pd.read_csv(r"C:\Users\janak\OneDrive\Desktop\DE CW\land_areas_of_sri_lanka.csv")

areas.drop(columns=['Land ',' Inland waters','Unnamed: 4'],inplace=True)
areas.dropna(inplace=True)

replacement_dict = {'Moneragala': 'Monaragala', 'Nuwara Eliya': 'Nuwara-eliya'}
areas[' / District'] = areas[' / District'].replace(replacement_dict)
areas= areas[areas[' / District'].isin(districts_to_keep)]
areas[' / District'] = areas[' / District'].replace(replacement_mapping)

areas['Total '] = areas['Total '].astype('float64')
areas.columns = ['District','Area(km^2)']
areas
# Out:
#                District  Area(km^2)
# 2        Colombo Proper       698.7
# 6          Kandy Proper      1939.5
# 8   Nuwara Eliya Proper      1741.2
# 11     Deniyaya, Matara      1282.5
# 14        Jaffna Proper      1025.3
# 24    Kurunegala Proper      4815.8
# 31   Bibile, Monaragala      5638.7

# %%
merged_df = pd.merge(areas, population, how='inner', left_on='District', right_on='District')
merged_df
# Out:
#                District  Area(km^2)  Year  Population
# 0        Colombo Proper       698.7  2019     2448000
# 1        Colombo Proper       698.7  2020     2455000
# 2        Colombo Proper       698.7  2021     2480000
# 3        Colombo Proper       698.7  2022     2478000
# 4        Colombo Proper       698.7  2023     2460000
# 5          Kandy Proper      1939.5  2019     1476000
# 6          Kandy Proper      1939.5  2020     1483000
# 7          Kandy Proper      1939.5  2021     1501000
# 8          Kandy Proper      1939.5  2022     1499000
# 9          Kandy Proper      1939.5  2023     1482000
# 10  Nuwara Eliya Proper      1741.2  2019      768000
# 11  Nuwara Eliya Proper      1741.2  2020      773000
# 12  Nuwara Eliya Proper      1741.2  2021      780000
# 13  Nuwara Eliya Proper      1741.2  2022      783000
# 14  Nuwara Eliya Proper      1741.2  2023      781000
# 15     Deniyaya, Matara      1282.5  2019      863000
# 16     Deniyaya, Matara      1282.5  2020      866000
# 17     Deniyaya, Matara      1282.5  2021      873000
# 18     Deniyaya, Matara      1282.5  2022      874000
# 19     Deniyaya, Matara      1282.5  2023      869000
# 20        Jaffna Proper      1025.3  2019      617000
# 21        Jaffna Proper      1025.3  2020      621000
# 22        Jaffna Proper      1025.3  2021      626000
# 23        Jaffna Proper      1025.3  2022      629000
# 24        Jaffna Proper      1025.3  2023      628000
# 25    Kurunegala Proper      4815.8  2019     1719000
# 26    Kurunegala Proper      4815.8  2020     1726000
# 27    Kurunegala Proper      4815.8  2021     1743000
# 28    Kurunegala Proper      4815.8  2022     1742000
# 29    Kurunegala Proper      4815.8  2023     1727000
# 30   Bibile, Monaragala      5638.7  2019      496000
# 31   Bibile, Monaragala      5638.7  2020      501000
# 32   Bibile, Monaragala      5638.7  2021      505000
# 33   Bibile, Monaragala      5638.7  2022      509000
# 34   Bibile, Monaragala      5638.7  2023      509000

# %%
merged_df['Population_density'] = merged_df.apply(lambda row: row['Population'] / row['Area(km^2)'], axis=1)
merged_df
# Out:
#                District  Area(km^2)  Year  Population  Population_density
# 0        Colombo Proper       698.7  2019     2448000         3503.649635
# 1        Colombo Proper       698.7  2020     2455000         3513.668241
# 2        Colombo Proper       698.7  2021     2480000         3549.448977
# 3        Colombo Proper       698.7  2022     2478000         3546.586518
# 4        Colombo Proper       698.7  2023     2460000         3520.824388
# 5          Kandy Proper      1939.5  2019     1476000          761.020882
# 6          Kandy Proper      1939.5  2020     1483000          764.630059
# 7          Kandy Proper      1939.5  2021     1501000          773.910802
# 8          Kandy Proper      1939.5  2022     1499000          772.879608
# 9          Kandy Proper      1939.5  2023     1482000          764.114462
# 10  Nuwara Eliya Proper      1741.2  2019      768000          441.075121
# 11  Nuwara Eliya Proper      1741.2  2020      773000          443.946703
# 12  Nuwara Eliya Proper      1741.2  2021      780000          447.966919
# 13  Nuwara Eliya Proper      1741.2  2022      783000          449.689869
# 14  Nuwara Eliya Proper      1741.2  2023      781000          448.541236
# 15     Deniyaya, Matara      1282.5  2019      863000          672.904483
# 16     Deniyaya, Matara      1282.5  2020      866000          675.243665
# 17     Deniyaya, Matara      1282.5  2021      873000          680.701754
# 18     Deniyaya, Matara      1282.5  2022      874000          681.481481
# 19     Deniyaya, Matara      1282.5  2023      869000          677.582846
# 20        Jaffna Proper      1025.3  2019      617000          601.775090
# 21        Jaffna Proper      1025.3  2020      621000          605.676387
# 22        Jaffna Proper      1025.3  2021      626000          610.553009
# 23        Jaffna Proper      1025.3  2022      629000          613.478982
# 24        Jaffna Proper      1025.3  2023      628000          612.503657
# 25    Kurunegala Proper      4815.8  2019     1719000          356.950039
# 26    Kurunegala Proper      4815.8  2020     1726000          358.403588
# 27    Kurunegala Proper      4815.8  2021     1743000          361.933635
# 28    Kurunegala Proper      4815.8  2022     1742000          361.725985
# 29    Kurunegala Proper      4815.8  2023     1727000          358.611238
# 30   Bibile, Monaragala      5638.7  2019      496000           87.963538
# 31   Bibile, Monaragala      5638.7  2020      501000           88.850267
# 32   Bibile, Monaragala      5638.7  2021      505000           89.559650
# 33   Bibile, Monaragala      5638.7  2022      509000           90.269034
# 34   Bibile, Monaragala      5638.7  2023      509000           90.269034

# %%
# Get unique districts
districts = merged_df['District'].unique()

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(20, 10), sharex=True)

# Flatten axes for easy iteration
axes = axes.flatten()

# Iterate through each district
for i, district in enumerate(districts):
    # Filter data for the current district
    data = merged_df[merged_df['District'] == district]
    
    # Plot population density vs year
    sns.lineplot(data=data, x='Year', y='Population_density', marker='o', ax=axes[i])
    axes[i].set_title(f'{district} Population Density vs Year')
    axes[i].set_xlabel('Year')
    axes[i].set_ylabel('Population Density')

# Hide remaining axes
for j in range(len(districts), len(axes)):
    axes[j].axis('off')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
df['Year']=df['date'].dt.year
df.head(10)
# Out:
#         date  total  new  Year
# 0 2019-01-01    0.0  0.0  2019
# 1 2019-01-02    0.0  0.0  2019
# 2 2019-01-03    0.0  0.0  2019
# 3 2019-01-04    0.0  0.0  2019
# 4 2019-01-05    0.0  0.0  2019
# 5 2019-01-06    0.0  0.0  2019
# 6 2019-01-07    0.0  0.0  2019
# 7 2019-01-08    0.0  0.0  2019
# 8 2019-01-09    0.0  0.0  2019
# 9 2019-01-10    0.0  0.0  2019

# %%
final_df = pd.merge(df, merged_df, how='inner', left_on='Year', right_on='Year')
final_df.drop(columns=['Year'],inplace=True)
final_df=final_df[['District', 'Area(km^2)', 'Population', 'Population_density','date', 'total', 'new']]
final_df
# Out:
#                   District  Area(km^2)  Population  Population_density  \
# 0           Colombo Proper       698.7     2448000         3503.649635
# 1             Kandy Proper      1939.5     1476000          761.020882
# 2      Nuwara Eliya Proper      1741.2      768000          441.075121
# 3         Deniyaya, Matara      1282.5      863000          672.904483
# 4            Jaffna Proper      1025.3      617000          601.775090
# ...                    ...         ...         ...                 ...
# 12777  Nuwara Eliya Proper      1741.2      781000          448.541236
# 12778     Deniyaya, Matara      1282.5      869000          677.582846
# 12779        Jaffna Proper      1025.3      628000          612.503657
# 12780    Kurunegala Proper      4815.8     1727000          358.611238
# 12781   Bibile, Monaragala      5638.7      509000           90.269034
#
#             date     total  new
# 0     2019-01-01       0.0  0.0
# 1     2019-01-01       0.0  0.0
# 2     2019-01-01       0.0  0.0
# 3     2019-01-01       0.0  0.0
# 4     2019-01-01       0.0  0.0
# ...          ...       ...  ...
# 12777 2023-12-31  672039.0  0.0
# 12778 2023-12-31  672039.0  0.0
# 12779 2023-12-31  672039.0  0.0
# 12780 2023-12-31  672039.0  0.0
# 12781 2023-12-31  672039.0  0.0
#
# [12782 rows x 7 columns]
